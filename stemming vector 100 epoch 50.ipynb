# %%
import os
from nltk import word_tokenize 
from nltk.util import ngrams
import nltk, re, string, collections
from operator import itemgetter

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

import gensim
from gensim import corpora
from pprint import pprint
from gensim.utils import simple_preprocess

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.utils import lemmatize
from nltk.corpus import stopwords
import re
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)

# %%
import pandas as pd

# %%
def remove_stopwords(s):
    hasil_replace = s.replace("'", '').replace("&", '').replace("{", '').replace("}", '').replace("-", '').replace("/", '').replace("!", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '').replace('?', '').replace('`', '').replace(';', '')
    f = open('stopwordbahasa.csv', 'r')

    stopwords = []
    for lines in f:
        lines = lines.strip('\n')
        stopwords.append(lines)


    corpus_stopwrods = hasil_replace.split(' ')
    hasil_stopword = []

    for x in corpus_stopwrods:
        if x not in stopwords:
            hasil_stopword.append(x)


        
    hasil = " ".join(hasil_stopword)
    hasil = hasil.replace('\n', '')


    
    
    return(hasil)

# %%
def get_stemming(s):
    # create stemmer
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    output   = stemmer.stem(s)
    
    return output

# %%
data_file_path = 'tempo'

my_file = []
nama_files = []
corpus = []
a = 0
for root, dirs, files in os.walk(data_file_path):
    for my_file in files:
        #print(my_file)
        files = my_file.split(".")
        file_name = files[0]
        ctr = 0
        if my_file.endswith('.txt'):
            nama_file = os.path.join(root, my_file)
            
            data = open(nama_file)
            x = data.read().lower().replace('\n', ' ')
            teks = remove_stopwords(x)
            do_stemm = get_stemming(teks)
            print(nama_file, "-", a)
            filesname = nama_file.split('\\')
            #print(filesname[3])
            my_file = filesname[3].split(".")
            corpus.append(do_stemm)
            #print(my_file[0])
            nama_files.append(my_file[0])
            a = a +1
# Out:
# tempo\2000\000106\000106-111.txt - 0
# tempo\2000\000106\000106-1110.txt - 1
# tempo\2000\000106\000106-1111.txt - 2
# tempo\2000\000106\000106-1112.txt - 3
# tempo\2000\000106\000106-1113.txt - 4
# tempo\2000\000106\000106-1114.txt - 5
# tempo\2000\000106\000106-1115.txt - 6
# tempo\2000\000106\000106-1116.txt - 7
# tempo\2000\000106\000106-1117.txt - 8
# tempo\2000\000106\000106-1118.txt - 9
# tempo\2000\000106\000106-1119.txt - 10
# tempo\2000\000106\000106-112.txt - 11
# tempo\2000\000106\000106-1120.txt - 12
# tempo\2000\000106\000106-1121.txt - 13
# tempo\2000\000106\000106-1122.txt - 14
# tempo\2000\000106\000106-1123.txt - 15
# tempo\2000\000106\000106-1124.txt - 16
# tempo\2000\000106\000106-1125.txt - 17
# tempo\2000\000106\000106-1126.txt - 18
# tempo\2000\000106\000106-1127.txt - 19
# tempo\2000\000106\000106-1128.txt - 20
# tempo\2000\000106\000106-1129.txt - 21
# tempo\2000\000106\000106-113.txt - 22
# tempo\2000\000106\000106-1130.txt - 23
# ...

# %%
print(corpus[0:2])
# Out:
# ['ketua bps ganti pagi 315 resmi kepala biro pusat statistik soegito soewito ganti soedarti soerbakti jabat salah deputi bps rencana ganti 0900 istana negara jakarta berita turun acara ganti mulur soegito ganti ganti ganti pasuk pensiun usia 61 pensiun ban ganti kait kritik keras presiden gus dur tumbuh ekonomi nama soegito cuat tumbuh ekonomi indonesia turun drastis 4 persen 154 persen terang benar kepala bps soedarti benar data keluar soegito hitung soegito bps boleh hitung dasar data empiris dasar data statistik soedarti lanjut programprogram sempat deputi statistik distribusi necara nasional kusmadi saleh inflasi triwulan tingkat 1 persen inflasi 054 persen sebab rencana naik tarif dasar listrik akibat naik tarif angkut kota ajar didik', 'dana proyek manusia aceh ketua dpr akbar tanjung terang presiden gus dur dana us 2 juta sultan bolkiah brunei proyek manusia aceh wartawan gedung mprdpr rabu 315 akbar alas gus dur dana akbar aku dana duga gus dur sumbang anggar cukup alokasi se
# ...

# %%
import pickle

with open("list_stemming", 'rb') as fp:
    corpus = pickle.load(fp)

# %%
with open("nama_files", 'rb') as fp:
    nama_files = pickle.load(fp)

# %%
print(nama_files[0:2])
# Out:
# ['000106-111', '000106-1110']

# %%
print(corpus[0:2])
print(len(corpus))
# Out:
# ['ketua bps ganti pagi 315 resmi kepala biro pusat statistik soegito soewito ganti soedarti soerbakti jabat salah deputi bps rencana ganti 0900 istana negara jakarta berita turun acara ganti mulur soegito ganti ganti ganti pasuk pensiun usia 61 pensiun ban ganti kait kritik keras presiden gus dur tumbuh ekonomi nama soegito cuat tumbuh ekonomi indonesia turun drastis 4 persen 154 persen terang benar kepala bps soedarti benar data keluar soegito hitung soegito bps boleh hitung dasar data empiris dasar data statistik soedarti lanjut programprogram sempat deputi statistik distribusi necara nasional kusmadi saleh inflasi triwulan tingkat 1 persen inflasi 054 persen sebab rencana naik tarif dasar listrik akibat naik tarif angkut kota ajar didik', 'dana proyek manusia aceh ketua dpr akbar tanjung terang presiden gus dur dana us 2 juta sultan bolkiah brunei proyek manusia aceh wartawan gedung mprdpr rabu 315 akbar alas gus dur dana akbar aku dana duga gus dur sumbang anggar cukup alokasi se
# ...

# %%
my_data = pd.read_csv("tempoquery.csv")

drop_q1 = my_data['q1'].dropna().unique()
drop_q2 = my_data['q2'].dropna().unique()
drop_q3 = my_data['q3'].dropna().unique()
drop_q4 = my_data['q4'].dropna().unique()
drop_q5 = my_data['q5'].dropna().unique()
drop_q6 = my_data['q6'].dropna().unique()
drop_q7 = my_data['q7'].dropna().unique()
drop_q8 = my_data['q8'].dropna().unique()
drop_q9 = my_data['q9'].dropna().unique()
drop_q10 = my_data['q10'].dropna().unique()
drop_q11= my_data['q11'].dropna().unique()
drop_q12 = my_data['q12'].dropna().unique()
drop_q13 = my_data['q13'].dropna().unique()
drop_q14 = my_data['q14'].dropna().unique()
drop_q15 = my_data['q15'].dropna().unique()
drop_q16 = my_data['q16'].dropna().unique()
drop_q17 = my_data['q17'].dropna().unique()
drop_q18 = my_data['q18'].dropna().unique()
drop_q19 = my_data['q19'].dropna().unique()
drop_q20 = my_data['q20'].dropna().unique()
drop_q21 = my_data['q21'].dropna().unique()
drop_q22 = my_data['q22'].dropna().unique()
drop_q23 = my_data['q23'].dropna().unique()
drop_q24 = my_data['q24'].dropna().unique()
drop_q25 = my_data['q25'].dropna().unique()
drop_q26 = my_data['q26'].dropna().unique()
drop_q27 = my_data['q27'].dropna().unique()
drop_q28 = my_data['q28'].dropna().unique()
drop_q29 = my_data['q29'].dropna().unique()
drop_q30 = my_data['q30'].dropna().unique()
drop_q31 = my_data['q31'].dropna().unique()
drop_q32 = my_data['q32'].dropna().unique()
drop_q33 = my_data['q33'].dropna().unique()
drop_q34 = my_data['q34'].dropna().unique()
drop_q35 = my_data['q35'].dropna().unique()

tempo_qry_q1 = drop_q1.tolist()
tempo_qry_q2 = drop_q2.tolist()
tempo_qry_q3 = drop_q3.tolist()
tempo_qry_q4 = drop_q4.tolist()
tempo_qry_q5 = drop_q5.tolist()
tempo_qry_q6 = drop_q6.tolist()
tempo_qry_q7 = drop_q7.tolist()
tempo_qry_q8 = drop_q8.tolist()
tempo_qry_q9 = drop_q9.tolist()
tempo_qry_q10 = drop_q10.tolist()
tempo_qry_q11 = drop_q11.tolist()
tempo_qry_q12 = drop_q12.tolist()
tempo_qry_q13 = drop_q13.tolist()
tempo_qry_q14 = drop_q14.tolist()
tempo_qry_q15 = drop_q15.tolist()
tempo_qry_q16 = drop_q16.tolist()
tempo_qry_q17 = drop_q17.tolist()
tempo_qry_q18 = drop_q18.tolist()
tempo_qry_q19 = drop_q19.tolist()
tempo_qry_q20 = drop_q20.tolist()
tempo_qry_q21 = drop_q21.tolist()
tempo_qry_q22 = drop_q22.tolist()
tempo_qry_q23 = drop_q23.tolist()
tempo_qry_q24 = drop_q24.tolist()
tempo_qry_q25 = drop_q25.tolist()
tempo_qry_q26 = drop_q26.tolist()
tempo_qry_q27 = drop_q27.tolist()
tempo_qry_q28 = drop_q28.tolist()
tempo_qry_q29 = drop_q29.tolist()
tempo_qry_q30 = drop_q30.tolist()
tempo_qry_q31 = drop_q31.tolist()
tempo_qry_q32 = drop_q32.tolist()
tempo_qry_q33 = drop_q33.tolist()
tempo_qry_q34 = drop_q34.tolist()
tempo_qry_q35 = drop_q35.tolist()

print(len(tempo_qry_q4))
print(len(tempo_qry_q35))
# Out:
# 113
# 3

# %%
print(len(tempo_qry_q1))
print(len(tempo_qry_q2))
# Out:
# 97
# 343

# %%
my_corpus = [word_tokenize(i) for i in corpus]

# %%
print(my_corpus[0:2])
print(len(my_corpus))
# Out:
# [['ketua', 'bps', 'ganti', 'pagi', '315', 'resmi', 'kepala', 'biro', 'pusat', 'statistik', 'soegito', 'soewito', 'ganti', 'soedarti', 'soerbakti', 'jabat', 'salah', 'deputi', 'bps', 'rencana', 'ganti', '0900', 'istana', 'negara', 'jakarta', 'berita', 'turun', 'acara', 'ganti', 'mulur', 'soegito', 'ganti', 'ganti', 'ganti', 'pasuk', 'pensiun', 'usia', '61', 'pensiun', 'ban', 'ganti', 'kait', 'kritik', 'keras', 'presiden', 'gus', 'dur', 'tumbuh', 'ekonomi', 'nama', 'soegito', 'cuat', 'tumbuh', 'ekonomi', 'indonesia', 'turun', 'drastis', '4', 'persen', '154', 'persen', 'terang', 'benar', 'kepala', 'bps', 'soedarti', 'benar', 'data', 'keluar', 'soegito', 'hitung', 'soegito', 'bps', 'boleh', 'hitung', 'dasar', 'data', 'empiris', 'dasar', 'data', 'statistik', 'soedarti', 'lanjut', 'programprogram', 'sempat', 'deputi', 'statistik', 'distribusi', 'necara', 'nasional', 'kusmadi', 'saleh', 'inflasi', 'triwulan', 'tingkat', '1', 'persen', 'inflasi', '054', 'persen', 'sebab', 'rencana', 'naik', 
# ...

# %%
def create_tagged_document(list_of_list_of_words, nama_file):
    for i, list_of_words in enumerate(list_of_list_of_words):
        a = nama_file[i]
        yield gensim.models.doc2vec.TaggedDocument(list_of_words, [a])

documents = list(create_tagged_document(my_corpus, nama_files))

# %%
documents
# Out:
# [TaggedDocument(words=['ketua', 'bps', 'ganti', 'pagi', '315', 'resmi', 'kepala', 'biro', 'pusat', 'statistik', 'soegito', 'soewito', 'ganti', 'soedarti', 'soerbakti', 'jabat', 'salah', 'deputi', 'bps', 'rencana', 'ganti', '0900', 'istana', 'negara', 'jakarta', 'berita', 'turun', 'acara', 'ganti', 'mulur', 'soegito', 'ganti', 'ganti', 'ganti', 'pasuk', 'pensiun', 'usia', '61', 'pensiun', 'ban', 'ganti', 'kait', 'kritik', 'keras', 'presiden', 'gus', 'dur', 'tumbuh', 'ekonomi', 'nama', 'soegito', 'cuat', 'tumbuh', 'ekonomi', 'indonesia', 'turun', 'drastis', '4', 'persen', '154', 'persen', 'terang', 'benar', 'kepala', 'bps', 'soedarti', 'benar', 'data', 'keluar', 'soegito', 'hitung', 'soegito', 'bps', 'boleh', 'hitung', 'dasar', 'data', 'empiris', 'dasar', 'data', 'statistik', 'soedarti', 'lanjut', 'programprogram', 'sempat', 'deputi', 'statistik', 'distribusi', 'necara', 'nasional', 'kusmadi', 'saleh', 'inflasi', 'triwulan', 'tingkat', '1', 'persen', 'inflasi', '054', 'persen', 'sebab'
# ...

# %%
# Init the Doc2Vec model
model = gensim.models.doc2vec.Doc2Vec(vector_size=100, epochs=50, min_count=0, dm =0, alpha=0.025, min_alpha=0.025)
# Build the Volabulary
model.build_vocab(documents)
# Train the Doc2Vec model
model.train(documents, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# 2019-07-13 14:52:58,832 : INFO : collecting all words and their counts
# 2019-07-13 14:52:58,832 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-07-13 14:52:59,184 : INFO : PROGRESS: at example #10000, processed 1562489 words (4353889/s), 50704 word types, 9967 tags
# 2019-07-13 14:52:59,516 : INFO : PROGRESS: at example #20000, processed 3096387 words (4748671/s), 76326 word types, 19967 tags
# 2019-07-13 14:52:59,630 : INFO : collected 82941 word types and 22911 unique tags from a corpus of 22944 examples and 3540814 words
# 2019-07-13 14:52:59,630 : INFO : Loading a fresh vocabulary
# 2019-07-13 14:52:59,886 : INFO : effective_min_count=0 retains 82941 unique words (100% of original 82941, drops 0)
# 2019-07-13 14:52:59,886 : INFO : effective_min_count=0 leaves 3540814 word corpus (100% of original 3540814, drops 0)
# 2019-07-13 14:53:00,183 : INFO : deleting the raw counts dictionary of 82941 items
# ...

# %%
q1 = model.infer_vector(['kenaikan', 'subsidi', 'bbm'])
q2 = model.infer_vector(['konflik', 'bersenjata', 'gerakan', 'aceh', 'merdeka'])
q3 = model.infer_vector(['penyelewengan', 'dana', 'nonbudgeter', 'bulog'])
q4 = model.infer_vector(['kasus', 'buloggate', 'bruneigate', 'dana', 'yanatera'])
q5 = model.infer_vector(['perundingan', 'malino'])
q6 = model.infer_vector(['dekrit', 'maklumat', 'presiden'])
q7 = model.infer_vector(['kasus', 'kematian', 'pembunuhan', 'theys', 'eluay'])
q8 = model.infer_vector(['perkara', 'kasus', 'korupsi', 'kkn', 'soeharto'])
q9 = model.infer_vector(['kasus', 'karaha', 'bodas', 'pertamina'])
q10 = model.infer_vector(['peledakan', 'bom', 'medan'])
q11 = model.infer_vector(['perjanjian', 'kontrak', 'indonesia', 'imf'])
q12 = model.infer_vector(['sidang', 'kasus', 'bom', 'elize', 'tmii'])
q13 = model.infer_vector(['penangkapan', 'pencarian', 'keberadaan', 'buronan', 'tommy', 'soeharto'])
q14 = model.infer_vector(['sidang', 'istimewa', 'si', 'mpr'])
q15 = model.infer_vector(['kasus', 'peledakan', 'gedung', 'bej'])
q16 = model.infer_vector(['kasus', 'sidang', 'pelanggaran', 'ham', 'timor', 'timur'])
q17 = model.infer_vector(['kebakaran', 'hutan', 'asap', 'sumatera', 'kalimantan'])
q18 = model.infer_vector(['kecelakaan', 'pesawat', 'cassa', 'nc212', 'irian', 'jaya'])
q19 = model.infer_vector(['tki', 'imigran', 'ilegal', 'malaysia'])
q20 = model.infer_vector(['kasus', 'pembunuhan', 'hakim', 'agung', 'syafiuddin', 'kartasasmita'])
q21 = model.infer_vector(['penyelundupan', 'imigran', 'gelap', 'australia'])
q22 = model.infer_vector(['pencantuman', 'kembali', 'piagam', 'jakarta'])
q23 = model.infer_vector(['proses', 'pembahasan', 'amandemen', 'uud', '1945'])
q24 = model.infer_vector(['kerusuhan', 'konflik', 'poso'])
q25 = model.infer_vector(['kasus', 'pailit', 'manulife'])
q26 = model.infer_vector(['penahanan', 'agus', 'dwikarna', 'tamsil', 'linrung', 'balfas', 'filipina'])
q27 = model.infer_vector(['penonaktifan', 'kapolri', 'bimantoro'])
q28 = model.infer_vector(['proses', 'pembentukan', 'komisi', 'konstitusi'])
q29 = model.infer_vector(['konflik', 'antar', 'etnis', 'sampit'])
q30 = model.infer_vector(['penangkapan', 'penahanan', 'panglima', 'laskar', 'jihad', 'jafar', 'umar'])
q31 = model.infer_vector(['pembahasan', 'proses', 'pemilihan', 'presiden', 'secara', 'langsung'])
q32 = model.infer_vector(['banjir', 'dki', 'jakarta'])
q33 = model.infer_vector(['pelimpahan', 'wewenang', 'presiden', 'kepada', 'wapres', 'wakil', 'presiden'])
q34 = model.infer_vector(['penggalian', 'harta', 'karun', 'menteri', 'agama', 'said', 'agil'])
q35 = model.infer_vector(['kasus', 'sengketa', 'sipadan', 'ligitan'])

# %%
similarity_q1 = model.docvecs.most_similar([q1], topn=97)
similarity_q2 = model.docvecs.most_similar([q2], topn=343)
similarity_q3 = model.docvecs.most_similar([q3], topn=264)
similarity_q4 = model.docvecs.most_similar([q4], topn=113)
similarity_q5 = model.docvecs.most_similar([q5], topn=32)
similarity_q6 = model.docvecs.most_similar([q6], topn=74)
similarity_q7 = model.docvecs.most_similar([q7], topn=126)
similarity_q8 = model.docvecs.most_similar([q8], topn=84)
similarity_q9 = model.docvecs.most_similar([q9], topn=6)
similarity_q10 = model.docvecs.most_similar([q10], topn=9)
similarity_q11 = model.docvecs.most_similar([q11], topn=50)
similarity_q12 = model.docvecs.most_similar([q12], topn=32)
similarity_q13 = model.docvecs.most_similar([q13], topn=106)
similarity_q14 = model.docvecs.most_similar([q14], topn=128)
similarity_q15 = model.docvecs.most_similar([q15], topn=36)
similarity_q16 = model.docvecs.most_similar([q16], topn=108)
similarity_q17 = model.docvecs.most_similar([q17], topn=11)
similarity_q18 = model.docvecs.most_similar([q18], topn=28)
similarity_q19 = model.docvecs.most_similar([q19], topn=48)
similarity_q20 = model.docvecs.most_similar([q20], topn=102)
similarity_q21 = model.docvecs.most_similar([q21], topn=16)
similarity_q22 = model.docvecs.most_similar([q22], topn=7)
similarity_q23 = model.docvecs.most_similar([q23], topn=74)
similarity_q24 = model.docvecs.most_similar([q24], topn=47)
similarity_q25 = model.docvecs.most_similar([q25], topn=30)
similarity_q26 = model.docvecs.most_similar([q26], topn=77)
similarity_q27 = model.docvecs.most_similar([q27], topn=43)
similarity_q28 = model.docvecs.most_similar([q28], topn=14)
similarity_q29 = model.docvecs.most_similar([q29], topn=46)
similarity_q30 = model.docvecs.most_similar([q30], topn=51)
similarity_q31 = model.docvecs.most_similar([q31], topn=36)
similarity_q32 = model.docvecs.most_similar([q32], topn=89)
similarity_q33 = model.docvecs.most_similar([q33], topn=12)
similarity_q34 = model.docvecs.most_similar([q34], topn=2)
similarity_q35 = model.docvecs.most_similar([q35], topn=3)
# Out:
# 2019-07-13 14:56:09,858 : INFO : precomputing L2-norms of doc weight vectors

# %%
print(similarity_q1)
# Out:
# [('010905-1115', 0.6154763102531433), ('021601-1155', 0.6149711012840271), ('020801-1131', 0.6064111590385437), ('022802-1131', 0.6024250388145447), ('020801-1128', 0.5993648767471313), ('000809-1115', 0.5896713137626648), ('021801-1134', 0.5871248245239258), ('012210-1116', 0.5861607789993286), ('021605-1146', 0.584125280380249), ('011106-1117', 0.5812140703201294), ('020305-1130', 0.5795364379882812), ('020301-1128', 0.5783109664916992), ('021701-1129', 0.5777492523193359), ('020601-113', 0.5772883892059326), ('002709-116', 0.5769557356834412), ('021006-1112', 0.5768136978149414), ('011106-1119', 0.5758464336395264), ('011203-119', 0.5740269422531128), ('012303-115', 0.5736470222473145), ('021804-1130', 0.5735235214233398), ('012202-1128', 0.570860743522644), ('021105-112', 0.5669780969619751), ('021608-1114', 0.5663087964057922), ('001809-1129', 0.5661274194717407), ('021801-1120', 0.5661171078681946), ('020404-1143', 0.5650926232337952), ('011001-1138', 0.563866376876831), ('0127
# ...

# %%
similar_q1 = []
for x in range(len(similarity_q1)):
    hasil = similarity_q1[x][0]
    similar_q1.append(hasil)
    
similar_q2 = []
for x in range(len(similarity_q2)):
    hasil = similarity_q2[x][0]
    similar_q2.append(hasil)

similar_q3 = []
for x in range(len(similarity_q3)):
    hasil = similarity_q3[x][0]
    similar_q3.append(hasil)
    
similar_q4 = []
for x in range(len(similarity_q4)):
    hasil = similarity_q4[x][0]
    similar_q4.append(hasil)
    
similar_q5 = []
for x in range(len(similarity_q5)):
    hasil = similarity_q5[x][0]
    similar_q5.append(hasil)
    
similar_q6 = []
for x in range(len(similarity_q6)):
    hasil = similarity_q6[x][0]
    similar_q6.append(hasil)
    
similar_q7 = []
for x in range(len(similarity_q7)):
    hasil = similarity_q7[x][0]
    similar_q7.append(hasil)
    
similar_q8 = []
for x in range(len(similarity_q8)):
    hasil = similarity_q8[x][0]
    similar_q8.append(hasil)
    
similar_q9 = []
for x in range(len(similarity_q9)):
    hasil = similarity_q9[x][0]
    similar_q9.append(hasil)
    
similar_q10 = []
for x in range(len(similarity_q10)):
    hasil = similarity_q10[x][0]
    similar_q10.append(hasil)
    
similar_q11 = []
for x in range(len(similarity_q11)):
    hasil = similarity_q11[x][0]
    similar_q11.append(hasil)
    
similar_q12 = []
for x in range(len(similarity_q12)):
    hasil = similarity_q12[x][0]
    similar_q12.append(hasil)
    
similar_q13 = []
for x in range(len(similarity_q13)):
    hasil = similarity_q13[x][0]
    similar_q13.append(hasil)
    
similar_q14 = []
for x in range(len(similarity_q14)):
    hasil = similarity_q14[x][0]
    similar_q14.append(hasil)
    
similar_q15 = []
for x in range(len(similarity_q15)):
    hasil = similarity_q15[x][0]
    similar_q15.append(hasil)
    
similar_q16 = []
for x in range(len(similarity_q16)):
    hasil = similarity_q16[x][0]
    similar_q16.append(hasil)
    
similar_q17 = []
for x in range(len(similarity_q17)):
    hasil = similarity_q17[x][0]
    similar_q17.append(hasil)
    
similar_q18 = []
for x in range(len(similarity_q18)):
    hasil = similarity_q18[x][0]
    similar_q18.append(hasil)
    
similar_q19 = []
for x in range(len(similarity_q19)):
    hasil = similarity_q19[x][0]
    similar_q19.append(hasil)
    
similar_q20 = []
for x in range(len(similarity_q20)):
    hasil = similarity_q20[x][0]
    similar_q20.append(hasil)
    
similar_q21 = []
for x in range(len(similarity_q21)):
    hasil = similarity_q21[x][0]
    similar_q21.append(hasil)
    
similar_q22 = []
for x in range(len(similarity_q22)):
    hasil = similarity_q22[x][0]
    similar_q22.append(hasil)
    
similar_q23 = []
for x in range(len(similarity_q23)):
    hasil = similarity_q23[x][0]
    similar_q23.append(hasil)
    
similar_q24 = []
for x in range(len(similarity_q24)):
    hasil = similarity_q24[x][0]
    similar_q24.append(hasil)
    
similar_q25 = []
for x in range(len(similarity_q25)):
    hasil = similarity_q25[x][0]
    similar_q25.append(hasil)
    
similar_q26 = []
for x in range(len(similarity_q26)):
    hasil = similarity_q26[x][0]
    similar_q26.append(hasil)
    
similar_q27 = []
for x in range(len(similarity_q27)):
    hasil = similarity_q27[x][0]
    similar_q27.append(hasil)
    
similar_q28 = []
for x in range(len(similarity_q28)):
    hasil = similarity_q28[x][0]
    similar_q28.append(hasil)
    
similar_q29 = []
for x in range(len(similarity_q29)):
    hasil = similarity_q29[x][0]
    similar_q29.append(hasil)
    
similar_q30 = []
for x in range(len(similarity_q30)):
    hasil = similarity_q30[x][0]
    similar_q30.append(hasil)
    
similar_q31 = []
for x in range(len(similarity_q31)):
    hasil = similarity_q31[x][0]
    similar_q31.append(hasil)
    
similar_q32 = []
for x in range(len(similarity_q32)):
    hasil = similarity_q32[x][0]
    similar_q32.append(hasil)

similar_q33 = []
for x in range(len(similarity_q33)):
    hasil = similarity_q33[x][0]
    similar_q33.append(hasil)
    
similar_q34 = []
for x in range(len(similarity_q34)):
    hasil = similarity_q34[x][0]
    similar_q34.append(hasil)
    
similar_q35 = []
for x in range(len(similarity_q35)):
    hasil = similarity_q35[x][0]
    similar_q35.append(hasil)

# %%
print(similar_q1)
# Out:
# ['010905-1115', '021601-1155', '020801-1131', '022802-1131', '020801-1128', '000809-1115', '021801-1134', '012210-1116', '021605-1146', '011106-1117', '020305-1130', '020301-1128', '021701-1129', '020601-113', '002709-116', '021006-1112', '011106-1119', '011203-119', '012303-115', '021804-1130', '012202-1128', '021105-112', '021608-1114', '001809-1129', '021801-1120', '020404-1143', '011001-1138', '012711-1136', '011801-1154', '010902-1123', '021101-1120', '000109-111', '021608-1113', '021701-111', '000610-118', '000210-117', '021405-1118', '011202-1124', '001909-1131', '012210-1119', '012302-1138', '020503-1120', '010712-1133', '022105-1125', '020205-1153', '011106-1129', '020803-1121', '020305-1115', '000210-116', '010602-1146', '010506-1133', '021101-113', '011409-1123', '011403-1152', '010806-1127', '000709-1130', '011602-1114', '020104-1134', '011303-115', '010401-1118', '010809-1117', '020908-119', '003108-1135', '020708-1128', '023001-1135', '020502-111', '021507-119', '022802
# ...

# %%
print("Jumlah dokumen tala yang relevan dengan Q1:")
print(len(similar_q1))
q1_sama_sql = [c for c in similar_q1 if c in tempo_qry_q1]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q1_sama_sql))
persentase_q1 = len(q1_sama_sql) / len(similar_q1) * 100
print("persentase kemiripan:")
print(persentase_q1, '\n')

print("Jumlah dokumen tala yang relevan dengan Q2:")
print(len(similar_q2))
q2_sama_sql = [c for c in similar_q2 if c in tempo_qry_q2]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q2_sama_sql))
persentase_q2 = len(q2_sama_sql) / len(similar_q2) * 100
print("persentase kemiripan:")
print(persentase_q2, '\n')

print("Jumlah dokumen tala yang relevan dengan Q3:")
print(len(similar_q3))
q3_sama_sql = [c for c in similar_q3 if c in tempo_qry_q3]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q3_sama_sql))
persentase_q3 = len(q3_sama_sql) / len(similar_q3) * 100
print("persentase kemiripan:")
print(persentase_q3, '\n')

print("Jumlah dokumen tala yang relevan dengan Q4:")
print(len(similar_q4))
q4_sama_sql = [c for c in similar_q4 if c in tempo_qry_q4]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q4_sama_sql))
persentase_q4 = len(q4_sama_sql) / len(similar_q4) * 100
print("persentase kemiripan:")
print(persentase_q4, '\n')

print("Jumlah dokumen tala yang relevan dengan Q5:")
print(len(similar_q5))
q5_sama_sql = [c for c in similar_q5 if c in tempo_qry_q5]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q5_sama_sql))
persentase_q5 = len(q5_sama_sql) / len(similar_q5) * 100
print("persentase kemiripan:")
print(persentase_q5, '\n')

print("Jumlah dokumen tala yang relevan dengan Q6:")
print(len(similar_q6))
q6_sama_sql = [c for c in similar_q6 if c in tempo_qry_q6]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q6_sama_sql))
persentase_q6 = len(q6_sama_sql) / len(similar_q6) * 100
print("persentase kemiripan:")
print(persentase_q6, '\n')

print("Jumlah dokumen tala yang relevan dengan Q7:")
print(len(similar_q7))
q7_sama_sql = [c for c in similar_q7 if c in tempo_qry_q7]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q7_sama_sql))
persentase_q7 = len(q7_sama_sql) / len(similar_q7) * 100
print("persentase kemiripan:")
print(persentase_q7, '\n')

print("Jumlah dokumen tala yang relevan dengan Q8:")
print(len(similar_q8))
q8_sama_sql = [c for c in similar_q8 if c in tempo_qry_q8]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q8_sama_sql))
persentase_q8 = len(q8_sama_sql) / len(similar_q8) * 100
print("persentase kemiripan:")
print(persentase_q8, '\n')

print("Jumlah dokumen tala yang relevan dengan Q9:")
print(len(similar_q9))
q9_sama_sql = [c for c in similar_q9 if c in tempo_qry_q9]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q9_sama_sql))
persentase_q9 = len(q9_sama_sql) / len(similar_q9) * 100
print("persentase kemiripan:")
print(persentase_q9, '\n')

print("Jumlah dokumen tala yang relevan dengan Q10:")
print(len(similar_q10))
q10_sama_sql = [c for c in similar_q10 if c in tempo_qry_q10]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q10_sama_sql))
persentase_q10 = len(q10_sama_sql) / len(similar_q10) * 100
print("persentase kemiripan:")
print(persentase_q10, '\n')

print("Jumlah dokumen tala yang relevan dengan Q11:")
print(len(similar_q11))
q11_sama_sql = [c for c in similar_q11 if c in tempo_qry_q11]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q11_sama_sql))
persentase_q11 = len(q11_sama_sql) / len(similar_q11) * 100
print("persentase kemiripan:")
print(persentase_q11, '\n')

print("Jumlah dokumen tala yang relevan dengan Q12:")
print(len(similar_q12))
q12_sama_sql = [c for c in similar_q12 if c in tempo_qry_q12]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q12_sama_sql))
persentase_q12 = len(q12_sama_sql) / len(similar_q12) * 100
print("persentase kemiripan:")
print(persentase_q12, '\n')

print("Jumlah dokumen tala yang relevan dengan Q13:")
print(len(similar_q13))
q13_sama_sql = [c for c in similar_q13 if c in tempo_qry_q13]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q13_sama_sql))
persentase_q13 = len(q13_sama_sql) / len(similar_q13) * 100
print("persentase kemiripan:")
print(persentase_q13, '\n')

print("Jumlah dokumen tala yang relevan dengan Q14:")
print(len(similar_q14))
q14_sama_sql = [c for c in similar_q14 if c in tempo_qry_q14]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q14_sama_sql))
persentase_q14 = len(q14_sama_sql) / len(similar_q14) * 100
print("persentase kemiripan:")
print(persentase_q14, '\n')

print("Jumlah dokumen tala yang relevan dengan Q15:")
print(len(similar_q15))
q15_sama_sql = [c for c in similar_q15 if c in tempo_qry_q15]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q15_sama_sql))
persentase_q15 = len(q15_sama_sql) / len(similar_q15) * 100
print("persentase kemiripan:")
print(persentase_q15, '\n')

print("Jumlah dokumen tala yang relevan dengan Q16:")
print(len(similar_q16))
q16_sama_sql = [c for c in similar_q16 if c in tempo_qry_q16]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q16_sama_sql))
persentase_q16 = len(q16_sama_sql) / len(similar_q16) * 100
print("persentase kemiripan:")
print(persentase_q16, '\n')

print("Jumlah dokumen tala yang relevan dengan Q17:")
print(len(similar_q17))
q17_sama_sql = [c for c in similar_q17 if c in tempo_qry_q17]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q17_sama_sql))
persentase_q17 = len(q17_sama_sql) / len(similar_q17) * 100
print("persentase kemiripan:")
print(persentase_q17, '\n')

print("Jumlah dokumen tala yang relevan dengan Q18:")
print(len(similar_q18))
q18_sama_sql = [c for c in similar_q18 if c in tempo_qry_q18]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q18_sama_sql))
persentase_q18 = len(q18_sama_sql) / len(similar_q18) * 100
print("persentase kemiripan:")
print(persentase_q18, '\n')

print("Jumlah dokumen tala yang relevan dengan Q19:")
print(len(similar_q19))
q19_sama_sql = [c for c in similar_q19 if c in tempo_qry_q19]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q19_sama_sql))
persentase_q19 = len(q19_sama_sql) / len(similar_q19) * 100
print("persentase kemiripan:")
print(persentase_q19, '\n')

print("Jumlah dokumen tala yang relevan dengan Q20:")
print(len(similar_q20))
q20_sama_sql = [c for c in similar_q20 if c in tempo_qry_q20]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q20_sama_sql))
persentase_q20 = len(q20_sama_sql) / len(similar_q20) * 100
print("persentase kemiripan:")
print(persentase_q20, '\n')

print("Jumlah dokumen tala yang relevan dengan Q21:")
print(len(similar_q21))
q21_sama_sql = [c for c in similar_q21 if c in tempo_qry_q21]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q21_sama_sql))
persentase_q21 = len(q21_sama_sql) / len(similar_q21) * 100
print("persentase kemiripan:")
print(persentase_q21, '\n')

print("Jumlah dokumen tala yang relevan dengan Q22:")
print(len(similar_q22))
q22_sama_sql = [c for c in similar_q22 if c in tempo_qry_q22]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q22_sama_sql))
persentase_q22 = len(q22_sama_sql) / len(similar_q22) * 100
print("persentase kemiripan:")
print(persentase_q22, '\n')

print("Jumlah dokumen tala yang relevan dengan Q23:")
print(len(similar_q23))
q23_sama_sql = [c for c in similar_q23 if c in tempo_qry_q23]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q23_sama_sql))
persentase_q23 = len(q23_sama_sql) / len(similar_q23) * 100
print("persentase kemiripan:")
print(persentase_q23, '\n')

print("Jumlah dokumen tala yang relevan dengan Q24:")
print(len(similar_q24))
q24_sama_sql = [c for c in similar_q24 if c in tempo_qry_q24]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q24_sama_sql))
persentase_q24 = len(q24_sama_sql) / len(similar_q24) * 100
print("persentase kemiripan:")
print(persentase_q24, '\n')

print("Jumlah dokumen tala yang relevan dengan Q25:")
print(len(similar_q25))
q25_sama_sql = [c for c in similar_q25 if c in tempo_qry_q25]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q25_sama_sql))
persentase_q25 = len(q25_sama_sql) / len(similar_q25) * 100
print("persentase kemiripan:")
print(persentase_q25, '\n')

print("Jumlah dokumen tala yang relevan dengan Q26:")
print(len(similar_q26))
q26_sama_sql = [c for c in similar_q26 if c in tempo_qry_q26]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q26_sama_sql))
persentase_q26 = len(q26_sama_sql) / len(similar_q26) * 100
print("persentase kemiripan:")
print(persentase_q26, '\n')

print("Jumlah dokumen tala yang relevan dengan Q27:")
print(len(similar_q27))
q27_sama_sql = [c for c in similar_q27 if c in tempo_qry_q27]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q27_sama_sql))
persentase_q27 = len(q27_sama_sql) / len(similar_q27) * 100
print("persentase kemiripan:")
print(persentase_q27, '\n')

print("Jumlah dokumen tala yang relevan dengan Q28:")
print(len(similar_q28))
q28_sama_sql = [c for c in similar_q28 if c in tempo_qry_q28]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q28_sama_sql))
persentase_q28 = len(q28_sama_sql) / len(similar_q28) * 100
print("persentase kemiripan:")
print(persentase_q28, '\n')

print("Jumlah dokumen tala yang relevan dengan Q29:")
print(len(similar_q29))
q29_sama_sql = [c for c in similar_q29 if c in tempo_qry_q29]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q29_sama_sql))
persentase_q29 = len(q29_sama_sql) / len(similar_q29) * 100
print("persentase kemiripan:")
print(persentase_q29, '\n')

print("Jumlah dokumen tala yang relevan dengan Q30:")
print(len(similar_q30))
q30_sama_sql = [c for c in similar_q30 if c in tempo_qry_q30]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q30_sama_sql))
persentase_q30 = len(q30_sama_sql) / len(similar_q30) * 100
print("persentase kemiripan:")
print(persentase_q30, '\n')

print("Jumlah dokumen tala yang relevan dengan Q31:")
print(len(similar_q31))
q31_sama_sql = [c for c in similar_q31 if c in tempo_qry_q31]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q31_sama_sql))
persentase_q31 = len(q31_sama_sql) / len(similar_q31) * 100
print("persentase kemiripan:")
print(persentase_q31, '\n')

print("Jumlah dokumen tala yang relevan dengan Q32:")
print(len(similar_q32))
q32_sama_sql = [c for c in similar_q32 if c in tempo_qry_q32]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q32_sama_sql))
persentase_q32 = len(q32_sama_sql) / len(similar_q32) * 100
print("persentase kemiripan:")
print(persentase_q32, '\n')

print("Jumlah dokumen tala yang relevan dengan Q33:")
print(len(similar_q33))
q33_sama_sql = [c for c in similar_q33 if c in tempo_qry_q33]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q33_sama_sql))
persentase_q33 = len(q33_sama_sql) / len(similar_q33) * 100
print("persentase kemiripan:")
print(persentase_q33, '\n')

print("Jumlah dokumen tala yang relevan dengan Q34:")
print(len(similar_q34))
q34_sama_sql = [c for c in similar_q34 if c in tempo_qry_q34]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q34_sama_sql))
persentase_q34 = len(q34_sama_sql) / len(similar_q34) * 100
print("persentase kemiripan:")
print(persentase_q34, '\n')

print("Jumlah dokumen tala yang relevan dengan Q35:")
print(len(similar_q35))
q35_sama_sql = [c for c in similar_q35 if c in tempo_qry_q35]
print("Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:")
print(len(q35_sama_sql))
persentase_q35 = len(q35_sama_sql) / len(similar_q35) * 100
print("persentase kemiripan:")
print(persentase_q35, '\n')
# Out:
# Jumlah dokumen tala yang relevan dengan Q1:
# 97
# Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:
# 32
# persentase kemiripan:
# 32.98969072164948
#
# Jumlah dokumen tala yang relevan dengan Q2:
# 343
# Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:
# 54
# persentase kemiripan:
# 15.743440233236154
#
# Jumlah dokumen tala yang relevan dengan Q3:
# 264
# Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:
# 106
# persentase kemiripan:
# 40.15151515151515
#
# Jumlah dokumen tala yang relevan dengan Q4:
# 113
# Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:
# 30
# persentase kemiripan:
# 26.548672566371685
#
# Jumlah dokumen tala yang relevan dengan Q5:
# 32
# Jumlah dokumen yang sama antara dokumen hasil similarity dengan dokumen tala:
# 6
# persentase kemiripan:
# 18.75
#
# Jumlah dokumen tala yang relevan dengan Q6:
# 74
# ...

# %%
print("Nilai vektor q1")
print(q1, "\n")
print("Nilai vektor q2")
print(q2, "\n")
print("Nilai vektor q3")
print(q3, "\n")
print("Nilai vektor q4")
print(q4, "\n")
print("Nilai vektor q5")
print(q5, "\n")
print("Nilai vektor q6")
print(q6, "\n")
print("Nilai vektor q7")
print(q7, "\n")
print("Nilai vektor q8")
print(q8, "\n")
print("Nilai vektor q9")
print(q9, "\n")
print("Nilai vektor q10")
print(q10, "\n")
print("Nilai vektor q11")
print(q11, "\n")
print("Nilai vektor q12")
print(q12, "\n")
print("Nilai vektor q13")
print(q13, "\n")
print("Nilai vektor q14")
print(q14, "\n")
print("Nilai vektor q15")
print(q15, "\n")
print("Nilai vektor q16")
print(q16, "\n")
print("Nilai vektor q17")
print(q17, "\n")
print("Nilai vektor q18")
print(q18, "\n")
print("Nilai vektor q19")
print(q19, "\n")
print("Nilai vektor q20")
print(q20, "\n")
print("Nilai vektor q21")
print(q21, "\n")
print("Nilai vektor q22")
print(q22, "\n")
print("Nilai vektor q23")
print(q23, "\n")
print("Nilai vektor q24")
print(q24, "\n")
print("Nilai vektor q25")
print(q25, "\n")
print("Nilai vektor q26")
print(q26, "\n")
print("Nilai vektor q27")
print(q27, "\n")
print("Nilai vektor q28")
print(q28, "\n")
print("Nilai vektor q29")
print(q29, "\n")
print("Nilai vektor q30")
print(q30, "\n")
print("Nilai vektor q31")
print(q31, "\n")
print("Nilai vektor q32")
print(q32, "\n")
print("Nilai vektor q33")
print(q33, "\n")
print("Nilai vektor q34")
print(q34, "\n")
print("Nilai vektor q35")
print(q35, "\n")
# Out:
# Nilai vektor q1
# [-0.24057905  0.26917064 -0.14696069  0.03597009 -0.06967948  0.00869982
#  -0.14717823 -0.26770464 -0.1174181   0.19642116 -0.06160732 -0.46960187
#   0.06153014 -0.32007578 -0.06645036  0.16533014  0.09168085  0.01086998
#   0.25766793  0.34926188  0.36818853 -0.05920028 -0.05847647 -0.10140387
#   0.0703152  -0.00611161  0.11896304  0.14314175  0.51907617  0.42556798
#  -0.05929187  0.01772423 -0.33664805 -0.10964544  0.26415232 -0.00433965
#  -0.02653208  0.08099689  0.42114714 -0.12582913 -0.2034282  -0.09006572
#  -0.35955146  0.22581188 -0.16039287  0.17483243 -0.2864329  -0.11878059
#  -0.15199444 -0.03321141  0.4056612   0.08168454  0.32749805 -0.00056918
#   0.05101277 -0.2749643   0.12391334  0.04811633  0.080775    0.01073651
#  -0.01996765  0.0487359   0.01740385  0.1183347  -0.24389724  0.14730492
#  -0.4239155  -0.35357046  0.14190519 -0.30673853  0.1004044   0.16719711
#   0.00699579 -0.3406931  -0.29106107  0.2522754   0.00116308 -0.21655577
# ...

# %%
print("hasil similarity q1")
print(similarity_q1, '\n')
print("hasil similarity q2")
print(similarity_q2, '\n')
print("hasil similarity q3")
print(similarity_q3, '\n')
print("hasil similarity q4")
print(similarity_q4, '\n')
print("hasil similarity q5")
print(similarity_q5, '\n')
print("hasil similarity q6")
print(similarity_q6, '\n')
print("hasil similarity q7")
print(similarity_q7, '\n')
print("hasil similarity q8")
print(similarity_q8, '\n')
print("hasil similarity q9")
print(similarity_q9, '\n')
print("hasil similarity q10")
print(similarity_q10, '\n')
print("hasil similarity q11")
print(similarity_q11, '\n')
print("hasil similarity q12")
print(similarity_q12, '\n')
print("hasil similarity q13")
print(similarity_q13, '\n')
print("hasil similarity q14")
print(similarity_q14, '\n')
print("hasil similarity q15")
print(similarity_q15, '\n')
print("hasil similarity q16")
print(similarity_q16, '\n')
print("hasil similarity q17")
print(similarity_q17, '\n')
print("hasil similarity q18")
print(similarity_q18, '\n')
print("hasil similarity q19")
print(similarity_q19, '\n')
print("hasil similarity q20")
print(similarity_q20, '\n')
print("hasil similarity q21")
print(similarity_q21, '\n')
print("hasil similarity q22")
print(similarity_q22, '\n')
print("hasil similarity q23")
print(similarity_q23, '\n')
print("hasil similarity q24")
print(similarity_q24, '\n')
print("hasil similarity q25")
print(similarity_q25, '\n')
print("hasil similarity q26")
print(similarity_q26, '\n')
print("hasil similarity q27")
print(similarity_q27, '\n')
print("hasil similarity q28")
print(similarity_q28, '\n')
print("hasil similarity q29")
print(similarity_q29, '\n')
print("hasil similarity q30")
print(similarity_q30, '\n')
print("hasil similarity q31")
print(similarity_q31, '\n')
print("hasil similarity q32")
print(similarity_q32, '\n')
print("hasil similarity q33")
print(similarity_q33, '\n')
print("hasil similarity q34")
print(similarity_q34, '\n')
print("hasil similarity q35")
print(similarity_q35, '\n')
# Out:
# hasil similarity q1
# ...
