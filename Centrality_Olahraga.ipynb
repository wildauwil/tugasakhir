# %%
from nltk import word_tokenize 
from nltk.util import ngrams
import nltk, re, string, collections
from operator import itemgetter
import csv

# %%
teks1 = open("olahraga/sept_olahraga_1.txt", "r")
sept_o_1 = teks1.read()
sept_o_1 = sept_o_1.lower()

teks2 = open("olahraga/sept_olahraga_2.txt", "r")
sept_o_2 = teks2.read()
sept_o_2 = sept_o_2.lower()

teks3 = open("olahraga/sept_olahraga_3.txt", "r")
sept_o_3 = teks3.read()
sept_o_3 = sept_o_3.lower()

teks4 = open("olahraga/okt_olahraga_1.txt", "r")
okt_o_1 = teks4.read()
okt_o_1 = okt_o_1.lower()

teks5 = open("olahraga/okt_olahraga_2.txt", "r")
okt_o_2 = teks5.read()
okt_o_2 = okt_o_2.lower()

teks6 = open("olahraga/okt_olahraga_3.txt", "r")
okt_o_3 = teks6.read()
okt_o_3 = okt_o_3.lower()

teks7 = open("olahraga/nov_olahraga_1.txt", "r")
nov_o_1 = teks7.read()
nov_o_1 = nov_o_1.lower()

teks8 = open("olahraga/nov_olahraga_2.txt", "r")
nov_o_2 = teks8.read()
nov_o_2 = nov_o_2.lower()

teks9 = open("olahraga/nov_olahraga_3.txt", "r")
nov_o_3 = teks9.read()
nov_o_3 = nov_o_3.lower()

teks10 = open("olahraga/des_olahraga_1.txt", "r")
des_o_1 = teks10.read()
des_o_1 = des_o_1.lower()

teks11 = open("olahraga/des_olahraga_2.txt", "r")
des_o_2 = teks11.read()
des_o_2 = des_o_2.lower()

teks12 = open("olahraga/des_olahraga_3.txt", "r")
des_o_3 = teks12.read()
des_o_3 = des_o_3.lower()



print(sept_o_1)
print("\n" + des_o_3)
# Out:
# pelatih selangor fa ingin pertahankan ilham udin dan evan dimas
# ...

# %%
import os, glob
path = './olahraga'
for infile in glob.glob( os.path.join(path, '*.*') ):
    print("current file is: " + infile)
    
read_files = glob.glob("olahraga/*.txt")

with open("olahraga/result.txt", "wb") as outfile:
    for f in read_files:
        with open(f, "rb") as infile:
            outfile.write(infile.read())
            
gabung = open("olahraga/result.txt", "r")
gabungan_olahraga = gabung.read()
gabungan_olahraga = gabungan_olahraga.lower()

print(gabungan_olahraga)
# Out:
# current file is: ./olahraga\des_olahraga_1.txt
# current file is: ./olahraga\des_olahraga_2.txt
# current file is: ./olahraga\des_olahraga_3.txt
# current file is: ./olahraga\nov_olahraga_1.txt
# current file is: ./olahraga\nov_olahraga_2.txt
# current file is: ./olahraga\nov_olahraga_3.txt
# current file is: ./olahraga\okt_olahraga_1.txt
# current file is: ./olahraga\okt_olahraga_2.txt
# current file is: ./olahraga\okt_olahraga_3.txt
# current file is: ./olahraga\result.txt
# current file is: ./olahraga\sept_olahraga_1.txt
# current file is: ./olahraga\sept_olahraga_2.txt
# current file is: ./olahraga\sept_olahraga_3.txt
# nama cristiano ronaldo haram diucapkan di rumah bintang inter milan
# ...

# %%
f = open('stopwordbahasa.csv', 'r')

stopwords = []
for lines in f:
    lines = lines.strip('\n')
    stopwords.append(lines)

#print(stopwords)
words = sept_o_1.split(' ')
words2 = sept_o_2.split(' ')
words3 = sept_o_3.split(' ')
words4 = okt_o_1.split(' ')
words5 = okt_o_2.split(' ')
words6 = okt_o_3.split(' ')
words7 = nov_o_1.split(' ')
words8 = nov_o_2.split(' ')
words9 = nov_o_3.split(' ')
words10 = des_o_1.split(' ')
words11 = des_o_2.split(' ')
words12 = des_o_3.split(' ')
words_gabungan = gabungan_olahraga.split(' ')

for x in words:
    if x in stopwords:
        words.remove(x)   
        
for x in words2:
    if x in stopwords:
        words2.remove(x) 
        
for x in words3:
    if x in stopwords:
        words3.remove(x) 
        
for x in words4:
    if x in stopwords:
        words4.remove(x) 
        
for x in words5:
    if x in stopwords:
        words5.remove(x) 
        
for x in words6:
    if x in stopwords:
        words6.remove(x) 
        
for x in words7:
    if x in stopwords:
        words7.remove(x) 
        
for x in words8:
    if x in stopwords:
        words8.remove(x) 
        
for x in words9:
    if x in stopwords:
        words9.remove(x) 
        
for x in words10:
    if x in stopwords:
        words10.remove(x) 
        
for x in words11:
    if x in stopwords:
        words11.remove(x) 
        
for x in words12:
    if x in stopwords:
        words12.remove(x) 
        
for x in words_gabungan:
    if x in stopwords:
        words_gabungan.remove(x) 

stop = " ".join(words)
stop2 = " ".join(words2)
stop3 = " ".join(words3)
stop4 = " ".join(words4)
stop5 = " ".join(words5)
stop6 = " ".join(words6)
stop7 = " ".join(words7)
stop8 = " ".join(words8)
stop9 = " ".join(words9)
stop10 = " ".join(words10)
stop11 = " ".join(words11)
stop12 = " ".join(words12)
stop_gabungan = " ".join(words_gabungan)

print(stop)
print("\n", stop5)
print("\n", stop_gabungan)
# Out:
# pelatih selangor fa pertahankan ilham udin evan dimas
# ...

# %%
stop_ol_sept_1 = stop.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_sept_2 = stop2.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_sept_3 = stop3.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_okt_1 = stop4.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_okt_2 = stop5.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_okt_3 = stop6.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_nov_1 = stop7.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_nov_2 = stop8.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_nov_3 = stop9.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_des_1 = stop10.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_des_2 = stop11.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_ol_des_3 = stop12.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')


stop_ol_gabungan = stop_gabungan.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')


print("\n", stop_ol_sept_1)
# Out:
#  pelatih selangor fa pertahankan ilham udin evan dimas
# ...

# %%
f2 = open('stopwordbahasa.csv', 'r')

stopwords2 = []
for lines in f2:
    lines = lines.strip('\n')
    stopwords2.append(lines)

#print(stopwords)
swords = stop_ol_sept_1.split(' ')
swords2 = stop_ol_sept_2.split(' ')
swords3 = stop_ol_sept_3.split(' ')
swords4 = stop_ol_okt_1.split(' ')
swords5 = stop_ol_okt_2.split(' ')
swords6 = stop_ol_okt_3.split(' ')
swords7 = stop_ol_nov_1.split(' ')
swords8 = stop_ol_nov_2.split(' ')
swords9 = stop_ol_nov_3.split(' ')
swords10 = stop_ol_des_1.split(' ')
swords11 = stop_ol_des_2.split(' ')
swords12 = stop_ol_des_3.split(' ')
swords_gabungan = stop_ol_gabungan.split(' ')

for x in swords:
    if x in stopwords2:
        swords.remove(x)   
        
for x in swords2:
    if x in stopwords2:
        swords2.remove(x) 
        
for x in swords3:
    if x in stopwords2:
        swords3.remove(x) 
        
for x in swords4:
    if x in stopwords2:
        swords4.remove(x) 
        
for x in swords5:
    if x in stopwords2:
        swords5.remove(x) 
        
for x in swords6:
    if x in stopwords2:
        swords6.remove(x) 
        
for x in swords7:
    if x in stopwords2:
        swords7.remove(x) 
        
for x in swords8:
    if x in stopwords2:
        swords8.remove(x) 
        
for x in swords9:
    if x in stopwords2:
        swords9.remove(x) 
        
for x in swords10:
    if x in stopwords2:
        swords10.remove(x) 
        
for x in swords11:
    if x in stopwords2:
        swords11.remove(x) 
        
for x in swords12:
    if x in stopwords2:
        swords12.remove(x) 
        
for x in swords_gabungan:
    if x in stopwords2:
        swords_gabungan.remove(x) 

teks1_ol_o = " ".join(swords)
teks2_ol_o = " ".join(swords2)
teks3_ol_o = " ".join(swords3)
teks4_ol_o = " ".join(swords4)
teks5_ol_o = " ".join(swords5)
teks6_ol_o = " ".join(swords6)
teks7_ol_o = " ".join(swords7)
teks8_ol_o = " ".join(swords8)
teks9_ol_o = " ".join(swords9)
teks10_ol_o = " ".join(swords10)
teks11_ol_o = " ".join(swords11)
teks12_ol_o = " ".join(swords12)
teks_gabungan_o = " ".join(swords_gabungan)

print(teks1_ol)
print("\n", teks5_ol)
print("\n", teks_gabungan_o)
# Out:
# ['pelatih selangor fa pertahankan ilham udin evan dimas\nkompascom - pelatih selangor fa muhammad nazliazmi ingin mempertahankan pemain timnas u-23 indonesia membela timnya ilham udin armaiyn evan dimas darmono diakuinya pemain memiliki permainan kompetisi liga malaysia musim 2018 tercatat evan dimas kesempatan bermain 20 pertandingan torehan gol liga malaysia 2018 ilham udin mencetak gol 16 pertandingan kontrak ilham evan musim hal sang pelatih komentar tergantung manajemen baca jadwal siaran langsung timnas u-16 indonesia piala asia u-16 2018 evan dimas ilham udin bisa bicara urusan jajaran manajemen selangor fa biarkan membahas nazliazmi ditemui bolasportcom bekasi jawa barat rabu 5/9/2018 evan ilham tampil penuh selangor fa terpaksa meninggalkan klub dipanggil memperkuat timnas u-23 indonesia persiapan asian games 2018 berdua delapan mereka kami musim depan nazliazmi selangor fa indonesia melakoni laga persahabatan melawan madura united persija jakarta tim berjulukan gergasi mera
# ...

# %%
teks1_ol = [teks1_ol_o]
teks2_ol = [teks2_ol_o]
teks3_ol = [teks3_ol_o]
teks4_ol = [teks4_ol_o]
teks5_ol = [teks5_ol_o]
teks6_ol = [teks6_ol_o]
teks7_ol = [teks7_ol_o]
teks8_ol = [teks8_ol_o]
teks9_ol = [teks9_ol_o]
teks10_ol = [teks10_ol_o]
teks11_ol = [teks11_ol_o]
teks12_ol = [teks12_ol_o]

teks_gabungan = [teks_gabungan_o]

print(teks1_ol)
# Out:
# ['pelatih selangor fa pertahankan ilham udin evan dimas\nkompascom - pelatih selangor fa muhammad nazliazmi ingin mempertahankan pemain timnas u-23 indonesia membela timnya ilham udin armaiyn evan dimas darmono diakuinya pemain memiliki permainan kompetisi liga malaysia musim 2018 tercatat evan dimas kesempatan bermain 20 pertandingan torehan gol liga malaysia 2018 ilham udin mencetak gol 16 pertandingan kontrak ilham evan musim hal sang pelatih komentar tergantung manajemen baca jadwal siaran langsung timnas u-16 indonesia piala asia u-16 2018 evan dimas ilham udin bisa bicara urusan jajaran manajemen selangor fa biarkan membahas nazliazmi ditemui bolasportcom bekasi jawa barat rabu 5/9/2018 evan ilham tampil penuh selangor fa terpaksa meninggalkan klub dipanggil memperkuat timnas u-23 indonesia persiapan asian games 2018 berdua delapan mereka kami musim depan nazliazmi selangor fa indonesia melakoni laga persahabatan melawan madura united persija jakarta tim berjulukan gergasi mera
# ...

# %%
hm = ''
bigram_ol_1 = []
bigram_ol_2 = []
bigram_ol_3 = []
bigram_ol_4 = []
bigram_ol_5 = []
bigram_ol_6 = []
bigram_ol_7 = []
bigram_ol_8 = []
bigram_ol_9 = []
bigram_ol_10 = []
bigram_ol_11 = []
bigram_ol_12 = []

bigram_ol_gabung = []

for line in teks1_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_1 = bigram_ol_1 + bigramku
    
for line in teks2_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_2 = bigram_ol_2 + bigramku
    
for line in teks3_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_3 = bigram_ol_3 + bigramku
    
for line in teks4_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_4 = bigram_ol_4 + bigramku
    
for line in teks5_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_5 = bigram_ol_5 + bigramku
    
for line in teks6_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_6 = bigram_ol_6 + bigramku
    
for line in teks7_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_7 = bigram_ol_7 + bigramku
    
for line in teks8_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_8 = bigram_ol_8 + bigramku
    
for line in teks9_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_9 = bigram_ol_9 + bigramku
    
for line in teks10_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_10 = bigram_ol_10 + bigramku
    
for line in teks11_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_11 = bigram_ol_11 + bigramku
    
for line in teks12_ol:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_12 = bigram_ol_12 + bigramku
    
for line in teks_gabungan:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_ol_gabung = bigram_ol_gabung + bigramku
    
print(bigram_ol_1)
# Out:
# [('pelatih', 'selangor'), ('selangor', 'fa'), ('fa', 'pertahankan'), ('pertahankan', 'ilham'), ('ilham', 'udin'), ('udin', 'evan'), ('evan', 'dimas'), ('dimas', 'kompascom'), ('kompascom', '-'), ('-', 'pelatih'), ('pelatih', 'selangor'), ('selangor', 'fa'), ('fa', 'muhammad'), ('muhammad', 'nazliazmi'), ('nazliazmi', 'ingin'), ('ingin', 'mempertahankan'), ('mempertahankan', 'pemain'), ('pemain', 'timnas'), ('timnas', 'u-23'), ('u-23', 'indonesia'), ('indonesia', 'membela'), ('membela', 'timnya'), ('timnya', 'ilham'), ('ilham', 'udin'), ('udin', 'armaiyn'), ('armaiyn', 'evan'), ('evan', 'dimas'), ('dimas', 'darmono'), ('darmono', 'diakuinya'), ('diakuinya', 'pemain'), ('pemain', 'memiliki'), ('memiliki', 'permainan'), ('permainan', 'kompetisi'), ('kompetisi', 'liga'), ('liga', 'malaysia'), ('malaysia', 'musim'), ('musim', '2018'), ('2018', 'tercatat'), ('tercatat', 'evan'), ('evan', 'dimas'), ('dimas', 'kesempatan'), ('kesempatan', 'bermain'), ('bermain', '20'), ('20', 'pertandingan')
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G1 = nx.Graph()
G2 = nx.Graph()
G3 = nx.Graph()
G4 = nx.Graph()
G5 = nx.Graph()
G6 = nx.Graph()
G7 = nx.Graph()
G8 = nx.Graph()
G9 = nx.Graph()
G10 = nx.Graph()
G11 = nx.Graph()
G12 = nx.Graph()

G_gabung = nx.Graph()

# %%
G1.add_edges_from(bigram_ol_1)
G2.add_edges_from(bigram_ol_2)
G3.add_edges_from(bigram_ol_3)
G4.add_edges_from(bigram_ol_4)
G5.add_edges_from(bigram_ol_5)
G6.add_edges_from(bigram_ol_6)
G7.add_edges_from(bigram_ol_7)
G8.add_edges_from(bigram_ol_8)
G9.add_edges_from(bigram_ol_9)
G10.add_edges_from(bigram_ol_10)
G11.add_edges_from(bigram_ol_11)
G12.add_edges_from(bigram_ol_12)

G_gabung.add_edges_from(bigram_ol_gabung)

G1.edges()
# Out:
# EdgeView([('pelatih', 'selangor'), ('pelatih', '-'), ('pelatih', 'sang'), ('pelatih', 'komentar'), ('selangor', 'fa'), ('selangor', 'manajemen'), ('selangor', 'penuh'), ('selangor', 'nazliazmi'), ('selangor', 'rencananya'), ('fa', 'pertahankan'), ('fa', 'muhammad'), ('fa', 'biarkan'), ('fa', 'terpaksa'), ('fa', 'indonesia'), ('fa', 'berujicoba'), ('pertahankan', 'ilham'), ('ilham', 'udin'), ('ilham', 'timnya'), ('ilham', '2018'), ('ilham', 'kontrak'), ('ilham', 'evan'), ('ilham', 'dimas'), ('ilham', 'tampil'), ('udin', 'evan'), ('udin', 'armaiyn'), ('udin', 'mencetak'), ('udin', 'bisa'), ('udin', 'laga'), ('evan', 'dimas'), ('evan', 'armaiyn'), ('evan', 'tercatat'), ('evan', 'musim'), ('evan', '2018'), ('evan', '5/9/2018'), ('evan', 'memainkan'), ('dimas', 'kompascom'), ('dimas', 'darmono'), ('dimas', 'kesempatan'), ('kompascom', '-'), ('muhammad', 'nazliazmi'), ('nazliazmi', 'ingin'), ('nazliazmi', 'membahas'), ('nazliazmi', 'ditemui'), ('nazliazmi', 'depan'), ('nazliazmi', '6/9/201
# ...

# %%
nx.draw_random(G1, with_labels=True, dpi = 1000)
# nx.draw_spectral(g)
# plt.savefig('graph.png')
plt.draw()
plt.show()

# %%
nx.draw_random(G_gabung, with_labels=True)
# nx.draw_spectral(g)
# plt.savefig('graph.png')
plt.draw()
plt.show()

# %%
print(G1.number_of_nodes())
print(G2.number_of_nodes())
print(G3.number_of_nodes())
print(G4.number_of_nodes())
print(G5.number_of_nodes())
print(G6.number_of_nodes())
print(G7.number_of_nodes())
print(G8.number_of_nodes())
print(G9.number_of_nodes())
print(G10.number_of_nodes())
print(G11.number_of_nodes())
print(G12.number_of_nodes())

print(G_gabung.number_of_nodes())
# Out:
# 122
# 178
# 79
# 111
# 106
# 80
# 88
# 113
# 96
# 84
# 95
# 140
# 1026

# %%
G_gabung.number_of_edges()
# Out:
# 1883

# %%
total_degree = 0

for node in G1.nodes():
    print(node, G1.degree(node))
    total_degree = total_degree + G1.degree(node)
#menampilkan nodes dengan jumlah degree nya masing-masing

print(total_degree/Gd.number_of_nodes())
# Out:
# pelatih 4
# selangor 6
# fa 7
# pertahankan 2
# ilham 8
# udin 6
# evan 9
# dimas 5
# kompascom 2
# - 2
# muhammad 2
# nazliazmi 10
# ingin 2
# mempertahankan 2
# pemain 6
# timnas 5
# u-23 2
# indonesia 7
# membela 2
# timnya 2
# armaiyn 2
# darmono 2
# diakuinya 2
# memiliki 2
# permainan 2
# kompetisi 2
# liga 3
# malaysia 3
# musim 6
# 2018 8
# tercatat 2
# kesempatan 2
# bermain 2
# 20 2
# pertandingan 4
# torehan 2
# gol 4
# mencetak 2
# 16 2
# kontrak 2
# hal 2
# sang 2
# komentar 2
# tergantung 2
# manajemen 4
# baca 2
# jadwal 2
# siaran 2
# langsung 2
# u-16 4
# piala 2
# asia 2
# bisa 2
# bicara 2
# urusan 2
# jajaran 2
# biarkan 2
# membahas 2
# ditemui 2
# bolasportcom 2
# bekasi 3
# jawa 2
# barat 3
# rabu 2
# 5/9/2018 2
# tampil 2
# penuh 2
# terpaksa 2
# meninggalkan 2
# klub 2
# dipanggil 2
# memperkuat 2
# persiapan 2
# asian 2
# games 2
# berdua 2
# delapan 2
# mereka 2
# kami 2
# depan 2
# melakoni 2
# laga 8
# persahabatan 2
# melawan 4
# madura 5
# united 3
# ...

# %% [markdown]
# # Degree centrality

# %%
degree_dict_ol1 = dict(G1.degree(G1.nodes()))  #menyimpan nilai degree dari setiap verteks ke dalam dictionary
degree_dict_ol2 = dict(G2.degree(G2.nodes()))
degree_dict_ol3 = dict(G3.degree(G3.nodes()))
degree_dict_ol4 = dict(G4.degree(G4.nodes()))
degree_dict_ol5 = dict(G5.degree(G5.nodes()))
degree_dict_ol6 = dict(G6.degree(G6.nodes()))
degree_dict_ol7 = dict(G7.degree(G7.nodes()))
degree_dict_ol8 = dict(G8.degree(G8.nodes()))
degree_dict_ol9 = dict(G9.degree(G9.nodes()))
degree_dict_ol10 = dict(G10.degree(G10.nodes()))
degree_dict_ol11 = dict(G11.degree(G11.nodes()))
degree_dict_ol12 = dict(G12.degree(G12.nodes()))

degree_dict_gabung = dict(G_gabung.degree(G_gabung.nodes()))

# %%
print(degree_dict_ol1)
print(len(degree_dict_ol1))

print(degree_dict_gabung)
print(len(degree_dict_gabung))
# Out:
# {'pelatih': 4, 'selangor': 6, 'fa': 7, 'pertahankan': 2, 'ilham': 8, 'udin': 6, 'evan': 9, 'dimas': 5, 'kompascom': 2, '-': 2, 'muhammad': 2, 'nazliazmi': 10, 'ingin': 2, 'mempertahankan': 2, 'pemain': 6, 'timnas': 5, 'u-23': 2, 'indonesia': 7, 'membela': 2, 'timnya': 2, 'armaiyn': 2, 'darmono': 2, 'diakuinya': 2, 'memiliki': 2, 'permainan': 2, 'kompetisi': 2, 'liga': 3, 'malaysia': 3, 'musim': 6, '2018': 8, 'tercatat': 2, 'kesempatan': 2, 'bermain': 2, '20': 2, 'pertandingan': 4, 'torehan': 2, 'gol': 4, 'mencetak': 2, '16': 2, 'kontrak': 2, 'hal': 2, 'sang': 2, 'komentar': 2, 'tergantung': 2, 'manajemen': 4, 'baca': 2, 'jadwal': 2, 'siaran': 2, 'langsung': 2, 'u-16': 4, 'piala': 2, 'asia': 2, 'bisa': 2, 'bicara': 2, 'urusan': 2, 'jajaran': 2, 'biarkan': 2, 'membahas': 2, 'ditemui': 2, 'bolasportcom': 2, 'bekasi': 3, 'jawa': 2, 'barat': 3, 'rabu': 2, '5/9/2018': 2, 'tampil': 2, 'penuh': 2, 'terpaksa': 2, 'meninggalkan': 2, 'klub': 2, 'dipanggil': 2, 'memperkuat': 2, 'persiapan': 2, '
# ...

# %%
#ini memanggil fungsi sorted yang diurutkan adalah setiap items dalam dictionary,
#lalu yang di sorted berdasarkan valuenya. reverse true itu dari paling besar ke paling kecil

sorted_degree_ol1 =sorted(degree_dict_ol1.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol2 =sorted(degree_dict_ol2.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol3 =sorted(degree_dict_ol3.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol4 =sorted(degree_dict_ol4.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol5 =sorted(degree_dict_ol5.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol6 =sorted(degree_dict_ol6.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol7 =sorted(degree_dict_ol7.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol8 =sorted(degree_dict_ol8.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol9 =sorted(degree_dict_ol9.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol10 =sorted(degree_dict_ol10.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol11 =sorted(degree_dict_ol11.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_ol12 =sorted(degree_dict_ol12.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_gabung =sorted(degree_dict_gabung.items(),
                    key=itemgetter(1),
                    reverse=True)

# %%
print(len(sorted_degree_ol1))
print(len(sorted_degree_ol2))
print(len(sorted_degree_gabung))
# Out:
# 122
# 178
# 1026

# %%
print("Top 10 nodes by degree olahraga 1:")
for d in sorted_degree_ol1[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 2:")
for d in sorted_degree_ol2[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 3:")
for d in sorted_degree_ol3[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 4:")
for d in sorted_degree_ol4[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 5:")
for d in sorted_degree_ol5[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 6:")
for d in sorted_degree_ol6[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 7:")
for d in sorted_degree_ol7[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 8:")
for d in sorted_degree_ol8[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 9:")
for d in sorted_degree_ol9[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 10:")
for d in sorted_degree_ol10[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 11:")
for d in sorted_degree_ol11[:10]:
    print(d)
    
print("\nTop 10 nodes by degree olahraga 12:")
for d in sorted_degree_ol12[:10]:
    print(d)
    
print("\nTop 20 nodes by degree olahraga Gabungan:")
for d in sorted_degree_gabung[:20]:
    print(d)
# Out:
# Top 10 nodes by degree olahraga 1:
# ('nazliazmi', 10)
# ('evan', 9)
# ('ilham', 8)
# ('2018', 8)
# ('laga', 8)
# ('fa', 7)
# ('indonesia', 7)
# ('selangor', 6)
# ('udin', 6)
# ('pemain', 6)
#
# Top 10 nodes by degree olahraga 2:
# ('kuningan', 23)
# ('peserta', 16)
# ('sepeda', 12)
# ('penggowes', 12)
# ('linggarjati', 11)
# ('olahraga', 9)
# ('gedung', 8)
# ('kemenpora', 8)
# ('â€', 8)
# ('“', 8)
#
# Top 10 nodes by degree olahraga 3:
# ('wakil', 10)
# ('vs', 10)
# ('indonesia', 7)
# ('perempat', 4)
# ('korea', 4)
# ('2018', 4)
# ('ganda', 4)
# ('1', 4)
# ('21-19', 4)
# ('14-21', 4)
#
# Top 10 nodes by degree olahraga 4:
# ('subangkit', 10)
# ('tim', 9)
# ('sriwijaya', 7)
# ('fc', 4)
# ('vs', 4)
# ('bali', 4)
# ('united', 4)
# ('palembang', 4)
# ('pelatih', 4)
# ('strategi', 4)
#
# Top 10 nodes by degree olahraga 5:
# ('lippi', 19)
# ('ancelotti', 19)
# ('napoli', 19)
# ('musim', 11)
# ('pelatih', 10)
# ('juventus', 10)
# ('sarri', 9)
# ('laga', 8)
# ('italia', 6)
# ('skuad', 5)
#
# ...

# %% [markdown]
# # betweeness, closeness, eigenvector Centrality

# %%
#betweenness centrality
betweenness_dict1 = nx.betweenness_centrality(G1)
betweenness_dict2 = nx.betweenness_centrality(G2) 
betweenness_dict3 = nx.betweenness_centrality(G3) 
betweenness_dict4 = nx.betweenness_centrality(G4) 
betweenness_dict5 = nx.betweenness_centrality(G5) 
betweenness_dict6 = nx.betweenness_centrality(G6) 
betweenness_dict7 = nx.betweenness_centrality(G7) 
betweenness_dict8 = nx.betweenness_centrality(G8) 
betweenness_dict9 = nx.betweenness_centrality(G9) 
betweenness_dict10 = nx.betweenness_centrality(G10) 
betweenness_dict11 = nx.betweenness_centrality(G11) 
betweenness_dict12 = nx.betweenness_centrality(G12) 
betweenness_dict_gabung = nx.betweenness_centrality(G_gabung)

# %%
#closeness centrality
closeness_dict1 = nx.closeness_centrality(G1)
closeness_dict2 = nx.closeness_centrality(G2)
closeness_dict3 = nx.closeness_centrality(G3)
closeness_dict4 = nx.closeness_centrality(G4)
closeness_dict5 = nx.closeness_centrality(G5)
closeness_dict6 = nx.closeness_centrality(G6)
closeness_dict7 = nx.closeness_centrality(G7)
closeness_dict8 = nx.closeness_centrality(G8)
closeness_dict9 = nx.closeness_centrality(G9)
closeness_dict10 = nx.closeness_centrality(G10)
closeness_dict11 = nx.closeness_centrality(G11)
closeness_dict12 = nx.closeness_centrality(G12)
closeness_dict_gabung = nx.closeness_centrality(G_gabung)

# %%
#eigenvector centrality
eigenvector_dict1 = nx.eigenvector_centrality(G1) 
eigenvector_dict2 = nx.eigenvector_centrality(G2) 
 
#eigenvector_dict4 = nx.eigenvector_centrality(G4) 
eigenvector_dict5 = nx.eigenvector_centrality(G5) 
eigenvector_dict6 = nx.eigenvector_centrality(G6) 
eigenvector_dict7 = nx.eigenvector_centrality(G7) 
eigenvector_dict8 = nx.eigenvector_centrality(G8) 
eigenvector_dict9 = nx.eigenvector_centrality(G9) 
eigenvector_dict10 = nx.eigenvector_centrality(G10) 
eigenvector_dict11 = nx.eigenvector_centrality(G11) 
eigenvector_dict12 = nx.eigenvector_centrality(G12) 
eigenvector_dict_gabung = nx.eigenvector_centrality(G_gabung) 

nx.set_node_attributes(G1, betweenness_dict1, 'betweenness')
nx.set_node_attributes(G1, closeness_dict1, 'closeness')
nx.set_node_attributes(G1, eigenvector_dict1, 'eigenvector')

# %%
eigenvector_dict3 = nx.eigenvector_centrality(G3)

# %%
betweenness_dict1
# Out:
# {'pelatih': 0.04234897678079495,
#  'selangor': 0.1689718614718613,
#  'fa': 0.17292650531286902,
#  'pertahankan': 0.03789212471030654,
#  'ilham': 0.15002120774848057,
#  'udin': 0.1891607088197997,
#  'evan': 0.17886385500021862,
#  'dimas': 0.06979666797848609,
#  'kompascom': 0.012320444706808334,
#  '-': 0.009682539682539678,
#  'muhammad': 0.01804249201976475,
#  'nazliazmi': 0.19979989286807467,
#  'ingin': 0.005973370064279155,
#  'mempertahankan': 0.00347544711181075,
#  'pemain': 0.10195406445406437,
#  'timnas': 0.0840884494293585,
#  'u-23': 0.006912359525995887,
#  'indonesia': 0.09930178407451133,
#  'membela': 0.004274782456600638,
#  'timnya': 0.006262516944335126,
#  'armaiyn': 0.0,
#  'darmono': 0.011331496786042235,
#  'diakuinya': 0.011419880624426091,
#  'memiliki': 0.018147382920110196,
#  'permainan': 0.007702020202020198,
#  'kompetisi': 0.006944444444444442,
#  'liga': 0.029338515020333196,
#  'malaysia': 0.03225403384494293,
#  'musim': 0.1062487974987974,
# ...

# %%
closeness_dict1
# Out:
# {'pelatih': 0.21453900709219859,
#  'selangor': 0.2505175983436853,
#  'fa': 0.26535087719298245,
#  'pertahankan': 0.24845995893223818,
#  'ilham': 0.2665198237885463,
#  'udin': 0.26419213973799127,
#  'evan': 0.2688888888888889,
#  'dimas': 0.2326923076923077,
#  'kompascom': 0.2,
#  '-': 0.1945337620578778,
#  'muhammad': 0.2326923076923077,
#  'nazliazmi': 0.25260960334029225,
#  'ingin': 0.20790378006872853,
#  'mempertahankan': 0.20648464163822525,
#  'pemain': 0.23818897637795275,
#  'timnas': 0.22532588454376165,
#  'u-23': 0.21080139372822299,
#  'indonesia': 0.25,
#  'membela': 0.21453900709219859,
#  'timnya': 0.21492007104795738,
#  'armaiyn': 0.22916666666666666,
#  'darmono': 0.2020033388981636,
#  'diakuinya': 0.20790378006872853,
#  'memiliki': 0.1970684039087948,
#  'permainan': 0.1753623188405797,
#  'kompetisi': 0.16875871687587168,
#  'liga': 0.19484702093397746,
#  'malaysia': 0.21880650994575046,
#  'musim': 0.25103734439834025,
#  '2018': 0.25366876310272535,
# ...

# %%
eigenvector_dict1
# Out:
# {'pelatih': 0.017617035399448335,
#  'selangor': 0.04120752357049082,
#  'fa': 0.064424886518503,
#  'pertahankan': 0.10005764921412161,
#  'ilham': 0.388011755622138,
#  'udin': 0.280851968338788,
#  'evan': 0.47364085152609925,
#  'dimas': 0.2260437329446817,
#  'kompascom': 0.0534660235002789,
#  '-': 0.015720640881498722,
#  'muhammad': 0.026132004628611063,
#  'nazliazmi': 0.05372016285219386,
#  'ingin': 0.01391344342717495,
#  'mempertahankan': 0.009180561165999936,
#  'pemain': 0.02759273149864599,
#  'timnas': 0.04281679327380127,
#  'u-23': 0.02573605609864576,
#  'indonesia': 0.07355014161469686,
#  'membela': 0.037055492473853036,
#  'timnya': 0.09400350255427886,
#  'armaiyn': 0.16685509262532164,
#  'darmono': 0.05397899430987694,
#  'diakuinya': 0.018040205313251807,
#  'memiliki': 0.006959810174251494,
#  'permainan': 0.003875026051854954,
#  'kompetisi': 0.01056147124463078,
#  'liga': 0.043882060988953725,
#  'malaysia': 0.15716750795824155,
# ...

# %% [markdown]
# # betweenness tertinggi

# %%
sorted_betweenness1 = sorted(betweenness_dict1.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness2 = sorted(betweenness_dict2.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness3 = sorted(betweenness_dict3.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness4 = sorted(betweenness_dict4.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness5 = sorted(betweenness_dict5.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness6 = sorted(betweenness_dict6.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness7 = sorted(betweenness_dict7.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness8 = sorted(betweenness_dict8.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness9 = sorted(betweenness_dict9.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness10 = sorted(betweenness_dict10.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness11 = sorted(betweenness_dict11.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness12 = sorted(betweenness_dict12.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness_gabung = sorted(betweenness_dict_gabung.items(),
                           key = itemgetter(1),
                           reverse=True)

print("Top 10 nodes by betweenness centrality olahraga 1:")
for b in sorted_betweenness1[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 2:")
for b in sorted_betweenness2[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 3:")
for b in sorted_betweenness3[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 4:")
for b in sorted_betweenness4[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 5:")
for b in sorted_betweenness5[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 6:")
for b in sorted_betweenness6[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 7:")
for b in sorted_betweenness7[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 8:")
for b in sorted_betweenness8[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 9:")
for b in sorted_betweenness9[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 10:")
for b in sorted_betweenness10[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 11:")
for b in sorted_betweenness11[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 12:")
for b in sorted_betweenness12[:10]:
    print(b)
    
print("\nTop 20 nodes by betweenness centrality olahraga gabung:")
for b in sorted_betweenness_gabung[:20]:
    print(b)
# Out:
# Top 10 nodes by betweenness centrality olahraga 1:
# ('laga', 0.26811502470593385)
# ('nazliazmi', 0.19979989286807467)
# ('udin', 0.1891607088197997)
# ('evan', 0.17886385500021862)
# ('fa', 0.17292650531286902)
# ('selangor', 0.1689718614718613)
# ('ilham', 0.15002120774848057)
# ('united', 0.13418579736761557)
# ('2018', 0.12488281079190176)
# ('musim', 0.1062487974987974)
#
# Top 10 nodes by betweenness centrality olahraga 2:
# ('kuningan', 0.3987287846560225)
# ('peserta', 0.23849245920683015)
# ('linggarjati', 0.18377491720874564)
# ('penggowes', 0.15165957108628927)
# ('sepeda', 0.12853216262314626)
# ('kemenpora', 0.10774218032902119)
# ('menggelar', 0.08525160848464627)
# ('hadir', 0.08298160748232782)
# ('wilayah', 0.08166388183261959)
# ('di', 0.07980108716470208)
#
# Top 10 nodes by betweenness centrality olahraga 3:
# ('vs', 0.503322074750646)
# ('indonesia', 0.46480107194392917)
# ('sugiarto', 0.3924012495441067)
# ('wakil', 0.25175618032760894)
# ...

# %% [markdown]
# # Closeness tertinggi

# %%
sorted_closeness1 = sorted(closeness_dict1.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness2 = sorted(closeness_dict2.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness3 = sorted(closeness_dict3.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness4 = sorted(closeness_dict4.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness5 = sorted(closeness_dict5.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness6 = sorted(closeness_dict6.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness7 = sorted(closeness_dict7.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness8 = sorted(closeness_dict8.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness9 = sorted(closeness_dict9.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness10 = sorted(closeness_dict10.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness11 = sorted(closeness_dict11.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness12 = sorted(closeness_dict12.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness_gabung = sorted(closeness_dict_gabung.items(),
                           key = itemgetter(1),
                           reverse=True)

print("Top 10 nodes by closeness centrality olahraga 1:")
for b in sorted_closeness1[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 2:")
for b in sorted_closeness2[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 3:")
for b in sorted_closeness3[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 4:")
for b in sorted_closeness4[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 5:")
for b in sorted_closeness5[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 6:")
for b in sorted_closeness6[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 7:")
for b in sorted_closeness7[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 8:")
for b in sorted_closeness8[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 9:")
for b in sorted_closeness9[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 10:")
for b in sorted_closeness10[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 11:")
for b in sorted_closeness11[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 12:")
for b in sorted_closeness12[:10]:
    print(b)
    
print("\nTop 20 nodes by closeness centrality olahraga gabung:")
for b in sorted_closeness_gabung[:20]:
    print(b)
# Out:
# Top 10 nodes by closeness centrality olahraga 1:
# ('laga', 0.2713004484304933)
# ('evan', 0.2688888888888889)
# ('ilham', 0.2665198237885463)
# ('fa', 0.26535087719298245)
# ('udin', 0.26419213973799127)
# ('2018', 0.25366876310272535)
# ('nazliazmi', 0.25260960334029225)
# ('musim', 0.25103734439834025)
# ('selangor', 0.2505175983436853)
# ('indonesia', 0.25)
#
# Top 10 nodes by closeness centrality olahraga 2:
# ('kuningan', 0.34235976789168276)
# ('linggarjati', 0.33084112149532713)
# ('peserta', 0.30998248686514884)
# ('berasal', 0.3089005235602094)
# ('di', 0.3046471600688468)
# ('penggowes', 0.3010204081632653)
# ('hadir', 0.2915980230642504)
# ('menggelar', 0.28733766233766234)
# ('pagi', 0.2845659163987138)
# ('wilayah', 0.2822966507177033)
#
# Top 10 nodes by closeness centrality olahraga 3:
# ('vs', 0.29545454545454547)
# ('sugiarto', 0.2932330827067669)
# ('indonesia', 0.2899628252788104)
# ('perempat', 0.24920127795527156)
# ('wakil', 0.2484076433121019)
# ...

# %% [markdown]
# # eigenvector tertinggi

# %%
sorted_eigenvector1 = sorted(eigenvector_dict1.items(),
                           key = itemgetter(1),
                           reverse=True)

print("Top 20 nodes by eigenvector centrality:")
for b in sorted_eigenvector1[:20]:
    print(b)
# Out:
# Top 20 nodes by eigenvector centrality:
# ('evan', 0.47364085152609925)
# ('2018', 0.39555029278158776)
# ('ilham', 0.388011755622138)
# ('udin', 0.280851968338788)
# ('musim', 0.2712534248462244)
# ('dimas', 0.2260437329446817)
# ('tercatat', 0.1922205160148878)
# ('armaiyn', 0.16685509262532164)
# ('malaysia', 0.15716750795824155)
# ('u-16', 0.12023096264398685)
# ('5/9/2018', 0.11049886848237245)
# ('memainkan', 0.11044365587854166)
# ('laga', 0.10704194005038033)
# ('pertahankan', 0.10005764921412161)
# ('timnya', 0.09400350255427886)
# ('games', 0.09309949039871115)
# ('berdua', 0.09298899342905105)
# ('tampil', 0.09234081444318398)
# ('kontrak', 0.09203645604730744)
# ('indonesia', 0.07355014161469686)
