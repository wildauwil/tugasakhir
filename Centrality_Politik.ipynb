# %%
from nltk import word_tokenize 
from nltk.util import ngrams
import nltk, re, string, collections
from operator import itemgetter
import csv

# %%
teks1 = open("politik/sept_politik_1.txt", "r")
sept_p_1 = teks1.read()
sept_p_1 = sept_p_1.lower()

teks2 = open("politik/sept_politik_2.txt", "r")
sept_p_2 = teks2.read()
sept_p_2 = sept_p_2.lower()

teks3 = open("politik/sept_politik_3.txt", "r")
sept_p_3 = teks3.read()
sept_p_3 = sept_p_3.lower()

teks4 = open("politik/okt_politik_1.txt", "r")
okt_p_1 = teks4.read()
okt_p_1 = okt_p_1.lower()

teks5 = open("politik/okt_politik_2.txt", "r")
okt_p_2 = teks5.read()
okt_p_2 = okt_p_2.lower()

teks6 = open("politik/okt_politik_3.txt", "r")
okt_p_3 = teks6.read()
okt_p_3 = okt_p_3.lower()

teks7 = open("politik/nov_politik_1.txt", "r")
nov_p_1 = teks7.read()
nov_p_1 = nov_p_1.lower()

teks8 = open("politik/nov_politik_2.txt", "r")
nov_p_2 = teks8.read()
nov_p_2 = nov_p_2.lower()

teks9 = open("politik/nov_politik_3.txt", "r")
nov_p_3 = teks9.read()
nov_p_3 = nov_p_3.lower()

teks10 = open("politik/des_politik_1.txt", "r")
des_p_1 = teks10.read()
des_p_1 = des_p_1.lower()

teks11 = open("politik/des_politik_2.txt", "r")
des_p_2 = teks11.read()
des_p_2 = des_p_2.lower()

teks12 = open("politik/des_politik_3.txt", "r")
des_p_3 = teks12.read()
des_p_3 = des_p_3.lower()



print(sept_p_1)
print("\n" + des_p_3)
# Out:
# fadli zon sebut keamanan dan kedamaian pemilu ditentukan penyelenggara
# ...

# %%
import os, glob
path = './politik'
for infile in glob.glob( os.path.join(path, '*.*') ):
    print("current file is: " + infile)
    
read_files = glob.glob("politik/*.txt")

with open("politik/result_p.txt", "wb") as outfile:
    for f in read_files:
        with open(f, "rb") as infile:
            outfile.write(infile.read())
            
gabung = open("politik/result_p.txt", "r")
gabungan_politik = gabung.read()
gabungan_politik = gabungan_politik.lower()

print(gabungan_politik)
# Out:
# current file is: ./politik\des_politik_1.txt
# current file is: ./politik\des_politik_2.txt
# current file is: ./politik\des_politik_3.txt
# current file is: ./politik\nov_politik_1.txt
# current file is: ./politik\nov_politik_2.txt
# current file is: ./politik\nov_politik_3.txt
# current file is: ./politik\okt_politik_1.txt
# current file is: ./politik\okt_politik_2.txt
# current file is: ./politik\okt_politik_3.txt
# current file is: ./politik\result_p.txt
# current file is: ./politik\sept_politik_1.txt
# current file is: ./politik\sept_politik_2.txt
# current file is: ./politik\sept_politik_3.txt
# mantan bupati purbalingga tasdi bersyukur ditangkap kpk
# ...

# %%
f = open('stopwordbahasa.csv', 'r')

stopwords = []
for lines in f:
    lines = lines.strip('\n')
    stopwords.append(lines)

#print(stopwords)
words = sept_p_1.split(' ')
words2 = sept_p_2.split(' ')
words3 = sept_p_3.split(' ')
words4 = okt_p_1.split(' ')
words5 = okt_p_2.split(' ')
words6 = okt_p_3.split(' ')
words7 = nov_p_1.split(' ')
words8 = nov_p_2.split(' ')
words9 = nov_p_3.split(' ')
words10 = des_p_1.split(' ')
words11 = des_p_2.split(' ')
words12 = des_p_3.split(' ')
words_gabungan = gabungan_politik.split(' ')

for x in words:
    if x in stopwords:
        words.remove(x)   
        
for x in words2:
    if x in stopwords:
        words2.remove(x) 
        
for x in words3:
    if x in stopwords:
        words3.remove(x) 
        
for x in words4:
    if x in stopwords:
        words4.remove(x) 
        
for x in words5:
    if x in stopwords:
        words5.remove(x) 
        
for x in words6:
    if x in stopwords:
        words6.remove(x) 
        
for x in words7:
    if x in stopwords:
        words7.remove(x) 
        
for x in words8:
    if x in stopwords:
        words8.remove(x) 
        
for x in words9:
    if x in stopwords:
        words9.remove(x) 
        
for x in words10:
    if x in stopwords:
        words10.remove(x) 
        
for x in words11:
    if x in stopwords:
        words11.remove(x) 
        
for x in words12:
    if x in stopwords:
        words12.remove(x) 
        
for x in words_gabungan:
    if x in stopwords:
        words_gabungan.remove(x) 

stop = " ".join(words)
stop2 = " ".join(words2)
stop3 = " ".join(words3)
stop4 = " ".join(words4)
stop5 = " ".join(words5)
stop6 = " ".join(words6)
stop7 = " ".join(words7)
stop8 = " ".join(words8)
stop9 = " ".join(words9)
stop10 = " ".join(words10)
stop11 = " ".join(words11)
stop12 = " ".join(words12)
stop_gabungan = " ".join(words_gabungan)

print(stop)
print("\n", stop5)
print("\n", stop_gabungan)
# Out:
# fadli zon keamanan kedamaian pemilu ditentukan penyelenggara
# ...

# %%
stop_p_sept_1 = stop.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_sept_2 = stop2.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_sept_3 = stop3.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_okt_1 = stop4.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_okt_2 = stop5.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_okt_3 = stop6.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_nov_1 = stop7.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_nov_2 = stop8.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_nov_3 = stop9.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_des_1 = stop10.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_des_2 = stop11.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')
stop_p_des_3 = stop12.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')


stop_p_gabungan = stop_gabungan.replace("'", '').replace(",",'').replace('''"''', '').replace('.', '').replace('(', '').replace(')', '').replace(':', '')


print("\n", stop_p_sept_1)
# Out:
#  fadli zon keamanan kedamaian pemilu ditentukan penyelenggara
# ...

# %%
f2 = open('stopwordbahasa.csv', 'r')

stopwords2 = []
for lines in f2:
    lines = lines.strip('\n')
    stopwords2.append(lines)

#print(stopwords)
swords = stop_p_sept_1.split(' ')
swords2 = stop_p_sept_2.split(' ')
swords3 = stop_p_sept_3.split(' ')
swords4 = stop_p_okt_1.split(' ')
swords5 = stop_p_okt_2.split(' ')
swords6 = stop_p_okt_3.split(' ')
swords7 = stop_p_nov_1.split(' ')
swords8 = stop_p_nov_2.split(' ')
swords9 = stop_p_nov_3.split(' ')
swords10 = stop_p_des_1.split(' ')
swords11 = stop_p_des_2.split(' ')
swords12 = stop_p_des_3.split(' ')
swords_gabungan = stop_p_gabungan.split(' ')

for x in swords:
    if x in stopwords2:
        swords.remove(x)   
        
for x in swords2:
    if x in stopwords2:
        swords2.remove(x) 
        
for x in swords3:
    if x in stopwords2:
        swords3.remove(x) 
        
for x in swords4:
    if x in stopwords2:
        swords4.remove(x) 
        
for x in swords5:
    if x in stopwords2:
        swords5.remove(x) 
        
for x in swords6:
    if x in stopwords2:
        swords6.remove(x) 
        
for x in swords7:
    if x in stopwords2:
        swords7.remove(x) 
        
for x in swords8:
    if x in stopwords2:
        swords8.remove(x) 
        
for x in swords9:
    if x in stopwords2:
        swords9.remove(x) 
        
for x in swords10:
    if x in stopwords2:
        swords10.remove(x) 
        
for x in swords11:
    if x in stopwords2:
        swords11.remove(x) 
        
for x in swords12:
    if x in stopwords2:
        swords12.remove(x) 
        
for x in swords_gabungan:
    if x in stopwords2:
        swords_gabungan.remove(x) 

teks1_p_o = " ".join(swords)
teks2_p_o = " ".join(swords2)
teks3_p_o = " ".join(swords3)
teks4_p_o = " ".join(swords4)
teks5_p_o = " ".join(swords5)
teks6_p_o = " ".join(swords6)
teks7_p_o = " ".join(swords7)
teks8_p_o = " ".join(swords8)
teks9_p_o = " ".join(swords9)
teks10_p_o = " ".join(swords10)
teks11_p_o = " ".join(swords11)
teks12_p_o = " ".join(swords12)
teks_gabungan_p = " ".join(swords_gabungan)

print(teks1_p_o)
print("\n", teks5_p_o)
print("\n", teks_gabungan_p)
# Out:
# fadli zon keamanan kedamaian pemilu ditentukan penyelenggara
# ...

# %%
teks1_p = [teks1_p_o]
teks2_p = [teks2_p_o]
teks3_p = [teks3_p_o]
teks4_p = [teks4_p_o]
teks5_p = [teks5_p_o]
teks6_p = [teks6_p_o]
teks7_p = [teks7_p_o]
teks8_p = [teks8_p_o]
teks9_p = [teks9_p_o]
teks10_p = [teks10_p_o]
teks11_p = [teks11_p_o]
teks12_p = [teks12_p_o]

teks_gabungan = [teks_gabungan_p]

print(teks1_p)
# Out:
# ['fadli zon keamanan kedamaian pemilu ditentukan penyelenggara\njakarta kompascom - wakil ketua dpr fadli zon pemilu aman damai ditentukan peserta tanggung pihak penyelenggara aparat pemerintahan fadli pemilu aman damai penyelenggara aparat berlaku adil penyelenggaranya adil kpu-nya adil bawaslunya adil aparat pemerintahan aparat birokrasi aparat keamanan adil akan tercipta keamanan kedamaian pemilu menggembirakan jakarta sabtu 1/9/2018 dikutip fadli zon kontestasi pemilu demokratis perbedaan lumrah perbedaan pandangan kompetisi demokrasi perbedaan pandangan mesti dikelola memecah belah lucu tidak ada perbedaan wakil ketua dpp partai gerindra kesempatan fadli menyinggung momen pelukan presiden joko widodo ketua partai gerindra prabowo subianto atlet pencak silat hanifan yudani kusumah arena asian games 2018 peristiwa dijadikan sinyal kontestasi pemilu berjalan damai aman jokowi prabowo bersaing pilpres 2019 jokowi berpasangan maruf amin resmi calon presiden wakil presiden baca fadli 
# ...

# %%
hm = ''
bigram_p_1 = []
bigram_p_2 = []
bigram_p_3 = []
bigram_p_4 = []
bigram_p_5 = []
bigram_p_6 = []
bigram_p_7 = []
bigram_p_8 = []
bigram_p_9 = []
bigram_p_10 = []
bigram_p_11 = []
bigram_p_12 = []

bigram_p_gabung = []

for line in teks1_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_1 = bigram_p_1 + bigramku
    
for line in teks2_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_2 = bigram_p_2 + bigramku
    
for line in teks3_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_3 = bigram_p_3 + bigramku
    
for line in teks4_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_4 = bigram_p_4 + bigramku
    
for line in teks5_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_5 = bigram_p_5 + bigramku
    
for line in teks6_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_6 = bigram_p_6 + bigramku
    
for line in teks7_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_7 = bigram_p_7 + bigramku
    
for line in teks8_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_8 = bigram_p_8 + bigramku
    
for line in teks9_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_9 = bigram_p_9 + bigramku
    
for line in teks10_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_10 = bigram_p_10 + bigramku
    
for line in teks11_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_11 = bigram_p_11 + bigramku
    
for line in teks12_p:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_12 = bigram_p_12 + bigramku
    
for line in teks_gabungan:
    token = nltk.word_tokenize(line)
    bigramku = list(nltk.bigrams(token))
    bigram_p_gabung = bigram_p_gabung + bigramku
    
print(bigram_p_1)
# Out:
# [('fadli', 'zon'), ('zon', 'keamanan'), ('keamanan', 'kedamaian'), ('kedamaian', 'pemilu'), ('pemilu', 'ditentukan'), ('ditentukan', 'penyelenggara'), ('penyelenggara', 'jakarta'), ('jakarta', 'kompascom'), ('kompascom', '-'), ('-', 'wakil'), ('wakil', 'ketua'), ('ketua', 'dpr'), ('dpr', 'fadli'), ('fadli', 'zon'), ('zon', 'pemilu'), ('pemilu', 'aman'), ('aman', 'damai'), ('damai', 'ditentukan'), ('ditentukan', 'peserta'), ('peserta', 'tanggung'), ('tanggung', 'pihak'), ('pihak', 'penyelenggara'), ('penyelenggara', 'aparat'), ('aparat', 'pemerintahan'), ('pemerintahan', 'fadli'), ('fadli', 'pemilu'), ('pemilu', 'aman'), ('aman', 'damai'), ('damai', 'penyelenggara'), ('penyelenggara', 'aparat'), ('aparat', 'berlaku'), ('berlaku', 'adil'), ('adil', 'penyelenggaranya'), ('penyelenggaranya', 'adil'), ('adil', 'kpu-nya'), ('kpu-nya', 'adil'), ('adil', 'bawaslunya'), ('bawaslunya', 'adil'), ('adil', 'aparat'), ('aparat', 'pemerintahan'), ('pemerintahan', 'aparat'), ('aparat', 'birokrasi'),
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G1 = nx.Graph()
G2 = nx.Graph()
G3 = nx.Graph()
G4 = nx.Graph()
G5 = nx.Graph()
G6 = nx.Graph()
G7 = nx.Graph()
G8 = nx.Graph()
G9 = nx.Graph()
G10 = nx.Graph()
G11 = nx.Graph()
G12 = nx.Graph()

G_gabung = nx.Graph()

# %%
G1.add_edges_from(bigram_p_1)
G2.add_edges_from(bigram_p_2)
G3.add_edges_from(bigram_p_3)
G4.add_edges_from(bigram_p_4)
G5.add_edges_from(bigram_p_5)
G6.add_edges_from(bigram_p_6)
G7.add_edges_from(bigram_p_7)
G8.add_edges_from(bigram_p_8)
G9.add_edges_from(bigram_p_9)
G10.add_edges_from(bigram_p_10)
G11.add_edges_from(bigram_p_11)
G12.add_edges_from(bigram_p_12)

G_gabung.add_edges_from(bigram_p_gabung)

G1.edges()
# Out:
# EdgeView([('fadli', 'zon'), ('fadli', 'dpr'), ('fadli', 'pemerintahan'), ('fadli', 'pemilu'), ('fadli', 'dikutip'), ('fadli', 'kesempatan'), ('fadli', 'menyinggung'), ('fadli', 'baca'), ('fadli', 'nasional'), ('zon', 'keamanan'), ('zon', 'pemilu'), ('zon', 'kontestasi'), ('zon', 'nilai'), ('zon', 'sampai'), ('keamanan', 'kedamaian'), ('keamanan', 'aparat'), ('keamanan', 'adil'), ('keamanan', 'tercipta'), ('kedamaian', 'pemilu'), ('pemilu', 'ditentukan'), ('pemilu', 'aman'), ('pemilu', 'menggembirakan'), ('pemilu', 'kontestasi'), ('pemilu', 'demokratis'), ('pemilu', 'berjalan'), ('ditentukan', 'penyelenggara'), ('ditentukan', 'damai'), ('ditentukan', 'peserta'), ('penyelenggara', 'jakarta'), ('penyelenggara', 'pihak'), ('penyelenggara', 'aparat'), ('penyelenggara', 'damai'), ('jakarta', 'kompascom'), ('jakarta', 'menggembirakan'), ('jakarta', 'sabtu'), ('jakarta', 'dki'), ('jakarta', 'sandiaga'), ('kompascom', '-'), ('-', 'wakil'), ('wakil', 'ketua'), ('wakil', 'perbedaan'), ('wakil',
# ...

# %%
nx.draw_random(G1, with_labels=True, dpi = 1000)
# nx.draw_spectral(g)
# plt.savefig('graph.png')
plt.draw()
plt.show()

# %%
nx.draw_random(G_gabung, with_labels=True)
# nx.draw_spectral(g)
# plt.savefig('graph.png')
plt.draw()
plt.show()

# %%
print(G1.number_of_nodes())
print(G2.number_of_nodes())
print(G3.number_of_nodes())
print(G4.number_of_nodes())
print(G5.number_of_nodes())
print(G6.number_of_nodes())
print(G7.number_of_nodes())
print(G8.number_of_nodes())
print(G9.number_of_nodes())
print(G10.number_of_nodes())
print(G11.number_of_nodes())
print(G12.number_of_nodes())

print(G_gabung.number_of_nodes())
# Out:
# 121
# 143
# 122
# 48
# 73
# 65
# 82
# 93
# 111
# 85
# 123
# 115
# 918

# %%
G_gabung.number_of_edges()
# Out:
# 1615

# %%
total_degree = 0

for node in G1.nodes():
    print(node, G1.degree(node))
    total_degree = total_degree + G1.degree(node)
#menampilkan nodes dengan jumlah degree nya masing-masing

print(total_degree/Gd.number_of_nodes())
# Out:
# fadli 9
# zon 6
# keamanan 5
# kedamaian 2
# pemilu 9
# ditentukan 4
# penyelenggara 5
# jakarta 6
# kompascom 2
# - 2
# wakil 6
# ketua 5
# dpr 2
# aman 3
# damai 4
# peserta 2
# tanggung 2
# pihak 2
# aparat 6
# pemerintahan 2
# berlaku 2
# adil 9
# penyelenggaranya 1
# kpu-nya 1
# bawaslunya 1
# birokrasi 1
# akan 2
# tercipta 2
# menggembirakan 2
# sabtu 2
# 1/9/2018 2
# dikutip 2
# kontestasi 3
# demokratis 2
# perbedaan 6
# lumrah 1
# pandangan 3
# kompetisi 2
# demokrasi 2
# mesti 2
# dikelola 2
# memecah 2
# belah 2
# lucu 2
# tidak 2
# ada 2
# dpp 2
# partai 8
# gerindra 4
# kesempatan 2
# menyinggung 2
# momen 2
# pelukan 2
# presiden 6
# joko 2
# widodo 2
# prabowo 7
# subianto 3
# atlet 2
# pencak 2
# silat 2
# hanifan 2
# yudani 2
# kusumah 2
# arena 2
# asian 2
# games 2
# 2018 2
# peristiwa 2
# dijadikan 2
# sinyal 2
# berjalan 2
# jokowi 4
# bersaing 2
# pilpres 2
# 2019 2
# berpasangan 2
# maruf 2
# amin 2
# resmi 2
# calon 3
# baca 2
# nilai 2
# bawaslu 2
# ...

# %% [markdown]
# # Degree centrality

# %%
degree_dict_pl1 = dict(G1.degree(G1.nodes()))  #menyimpan nilai degree dari setiap verteks ke dalam dictionary
degree_dict_pl2 = dict(G2.degree(G2.nodes()))
degree_dict_pl3 = dict(G3.degree(G3.nodes()))
degree_dict_pl4 = dict(G4.degree(G4.nodes()))
degree_dict_pl5 = dict(G5.degree(G5.nodes()))
degree_dict_pl6 = dict(G6.degree(G6.nodes()))
degree_dict_pl7 = dict(G7.degree(G7.nodes()))
degree_dict_pl8 = dict(G8.degree(G8.nodes()))
degree_dict_pl9 = dict(G9.degree(G9.nodes()))
degree_dict_pl10 = dict(G10.degree(G10.nodes()))
degree_dict_pl11 = dict(G11.degree(G11.nodes()))
degree_dict_pl12 = dict(G12.degree(G12.nodes()))

degree_dict_gabung = dict(G_gabung.degree(G_gabung.nodes()))

# %%
print(degree_dict_pl1)
print(len(degree_dict_pl1))

print(degree_dict_gabung)
print(len(degree_dict_gabung))
# Out:
# {'fadli': 9, 'zon': 6, 'keamanan': 5, 'kedamaian': 2, 'pemilu': 9, 'ditentukan': 4, 'penyelenggara': 5, 'jakarta': 6, 'kompascom': 2, '-': 2, 'wakil': 6, 'ketua': 5, 'dpr': 2, 'aman': 3, 'damai': 4, 'peserta': 2, 'tanggung': 2, 'pihak': 2, 'aparat': 6, 'pemerintahan': 2, 'berlaku': 2, 'adil': 9, 'penyelenggaranya': 1, 'kpu-nya': 1, 'bawaslunya': 1, 'birokrasi': 1, 'akan': 2, 'tercipta': 2, 'menggembirakan': 2, 'sabtu': 2, '1/9/2018': 2, 'dikutip': 2, 'kontestasi': 3, 'demokratis': 2, 'perbedaan': 6, 'lumrah': 1, 'pandangan': 3, 'kompetisi': 2, 'demokrasi': 2, 'mesti': 2, 'dikelola': 2, 'memecah': 2, 'belah': 2, 'lucu': 2, 'tidak': 2, 'ada': 2, 'dpp': 2, 'partai': 8, 'gerindra': 4, 'kesempatan': 2, 'menyinggung': 2, 'momen': 2, 'pelukan': 2, 'presiden': 6, 'joko': 2, 'widodo': 2, 'prabowo': 7, 'subianto': 3, 'atlet': 2, 'pencak': 2, 'silat': 2, 'hanifan': 2, 'yudani': 2, 'kusumah': 2, 'arena': 2, 'asian': 2, 'games': 2, '2018': 2, 'peristiwa': 2, 'dijadikan': 2, 'sinyal': 2, 'berjalan
# ...

# %%
#ini memanggil fungsi sorted yang diurutkan adalah setiap items dalam dictionary,
#lalu yang di sorted berdasarkan valuenya. reverse true itu dari paling besar ke paling kecil

sorted_degree_pl1 =sorted(degree_dict_pl1.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl2 =sorted(degree_dict_pl2.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl3 =sorted(degree_dict_pl3.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl4 =sorted(degree_dict_pl4.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl5 =sorted(degree_dict_pl5.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl6 =sorted(degree_dict_pl6.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl7 =sorted(degree_dict_pl7.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl8 =sorted(degree_dict_pl8.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl9 =sorted(degree_dict_pl9.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl10 =sorted(degree_dict_pl10.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl11 =sorted(degree_dict_pl11.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_pl12 =sorted(degree_dict_pl12.items(),
                    key=itemgetter(1),
                    reverse=True)

sorted_degree_gabung =sorted(degree_dict_gabung.items(),
                    key=itemgetter(1),
                    reverse=True)

# %%
print(len(sorted_degree_pl1))
print(len(sorted_degree_pl2))
print(len(sorted_degree_gabung))
# Out:
# 121
# 143
# 918

# %%
print("Top 10 nodes by degree politik 1:")
for d in sorted_degree_pl1[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 2:")
for d in sorted_degree_pl2[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 3:")
for d in sorted_degree_pl3[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 4:")
for d in sorted_degree_pl4[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 5:")
for d in sorted_degree_pl5[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 6:")
for d in sorted_degree_pl6[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 7:")
for d in sorted_degree_pl7[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 8:")
for d in sorted_degree_pl8[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 9:")
for d in sorted_degree_pl9[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 10:")
for d in sorted_degree_pl10[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 11:")
for d in sorted_degree_pl11[:10]:
    print(d)
    
print("\nTop 10 nodes by degree politik 12:")
for d in sorted_degree_pl12[:10]:
    print(d)
    
print("\nTop 20 nodes by degree politik Gabungan:")
for d in sorted_degree_gabung[:20]:
    print(d)
# Out:
# Top 10 nodes by degree politik 1:
# ('fadli', 9)
# ('pemilu', 9)
# ('adil', 9)
# ('partai', 8)
# ('prabowo', 7)
# ('zon', 6)
# ('jakarta', 6)
# ('wakil', 6)
# ('aparat', 6)
# ('perbedaan', 6)
#
# Top 10 nodes by degree politik 2:
# ('partai', 25)
# ('survei', 14)
# ('persen', 12)
# ('pkb', 9)
# ('pemilu', 9)
# ('golkar', 8)
# ('demokrat', 7)
# ('2019', 6)
# ('melibatkan', 6)
# ('responden', 6)
#
# Top 10 nodes by degree politik 3:
# ('yenny', 10)
# ('dur', 9)
# ('dukungan', 9)
# ('keluarga', 7)
# ('presiden', 7)
# ('politik', 7)
# ('jakarta', 6)
# ('wahid', 6)
# ('jokowi', 6)
# ('gus', 5)
#
# Top 10 nodes by degree politik 4:
# ('kpk', 10)
# ('ambon', 6)
# ('korupsi', 4)
# ('negara', 4)
# ('lokasi', 4)
# ('pemeriksaan', 4)
# ('ditangkap', 4)
# ('tangkap', 3)
# ('tangan', 3)
# ('6', 3)
#
# Top 10 nodes by degree politik 5:
# ('neneng', 11)
# ('rumah', 8)
# ('bekasi', 8)
# ('tersangka', 6)
# ('petugas', 5)
# ('korupsi', 4)
# ('kompascom', 4)
# ('cikarang', 4)
# ('buah', 4)
# ...

# %% [markdown]
# # betweeness, closeness, eigenvector Centrality

# %%
#betweenness centrality
betweenness_dict1 = nx.betweenness_centrality(G1)
betweenness_dict2 = nx.betweenness_centrality(G2) 
betweenness_dict3 = nx.betweenness_centrality(G3) 
betweenness_dict4 = nx.betweenness_centrality(G4) 
betweenness_dict5 = nx.betweenness_centrality(G5) 
betweenness_dict6 = nx.betweenness_centrality(G6) 
betweenness_dict7 = nx.betweenness_centrality(G7) 
betweenness_dict8 = nx.betweenness_centrality(G8) 
betweenness_dict9 = nx.betweenness_centrality(G9) 
betweenness_dict10 = nx.betweenness_centrality(G10) 
betweenness_dict11 = nx.betweenness_centrality(G11) 
betweenness_dict12 = nx.betweenness_centrality(G12) 
betweenness_dict_gabung = nx.betweenness_centrality(G_gabung)

# %%
#closeness centrality
closeness_dict1 = nx.closeness_centrality(G1)
closeness_dict2 = nx.closeness_centrality(G2)
closeness_dict3 = nx.closeness_centrality(G3)
closeness_dict4 = nx.closeness_centrality(G4)
closeness_dict5 = nx.closeness_centrality(G5)
closeness_dict6 = nx.closeness_centrality(G6)
closeness_dict7 = nx.closeness_centrality(G7)
closeness_dict8 = nx.closeness_centrality(G8)
closeness_dict9 = nx.closeness_centrality(G9)
closeness_dict10 = nx.closeness_centrality(G10)
closeness_dict11 = nx.closeness_centrality(G11)
closeness_dict12 = nx.closeness_centrality(G12)
closeness_dict_gabung = nx.closeness_centrality(G_gabung)

# %%
#eigenvector centrality
eigenvector_dict1 = nx.eigenvector_centrality(G1) 
eigenvector_dict2 = nx.eigenvector_centrality(G2) 
 
eigenvector_dict4 = nx.eigenvector_centrality(G4) 
eigenvector_dict5 = nx.eigenvector_centrality(G5) 
eigenvector_dict6 = nx.eigenvector_centrality(G6) 
eigenvector_dict7 = nx.eigenvector_centrality(G7) 
eigenvector_dict8 = nx.eigenvector_centrality(G8) 
eigenvector_dict9 = nx.eigenvector_centrality(G9) 
eigenvector_dict10 = nx.eigenvector_centrality(G10) 
eigenvector_dict11 = nx.eigenvector_centrality(G11) 
eigenvector_dict12 = nx.eigenvector_centrality(G12) 
eigenvector_dict_gabung = nx.eigenvector_centrality(G_gabung) 

nx.set_node_attributes(G1, betweenness_dict1, 'betweenness')
nx.set_node_attributes(G1, closeness_dict1, 'closeness')
nx.set_node_attributes(G1, eigenvector_dict1, 'eigenvector')

# %%
eigenvector_dict3 = nx.eigenvector_centrality(G3)

# %%
betweenness_dict1
# Out:
# {'fadli': 0.265109012524979,
#  'zon': 0.22759492919156782,
#  'keamanan': 0.09034929667282614,
#  'kedamaian': 0.01759447018900799,
#  'pemilu': 0.27873477790494594,
#  'ditentukan': 0.04202973108435294,
#  'penyelenggara': 0.06356161306791558,
#  'jakarta': 0.06990600280516246,
#  'kompascom': 0.013491750235447703,
#  '-': 0.01555057376485947,
#  'wakil': 0.14601633582726023,
#  'ketua': 0.07825912183055048,
#  'dpr': 0.042393644326417415,
#  'aman': 0.10008921012072278,
#  'damai': 0.023789158631595607,
#  'peserta': 0.011391223155929033,
#  'tanggung': 0.00014005602240896358,
#  'pihak': 0.0051353874883286665,
#  'aparat': 0.07800991064646526,
#  'pemerintahan': 0.03469572988480551,
#  'berlaku': 0.0,
#  'adil': 0.09976777307659666,
#  'penyelenggaranya': 0.0,
#  'kpu-nya': 0.0,
#  'bawaslunya': 0.0,
#  'birokrasi': 0.0,
#  'akan': 0.0007936507936507937,
#  'tercipta': 0.004887922534981361,
#  'menggembirakan': 0.02745098039215687,
#  'sabtu': 0.0035947712418300665,
# ...

# %%
closeness_dict1
# Out:
# {'fadli': 0.25263157894736843,
#  'zon': 0.24048096192384769,
#  'keamanan': 0.20905923344947736,
#  'kedamaian': 0.21428571428571427,
#  'pemilu': 0.255863539445629,
#  'ditentukan': 0.2158273381294964,
#  'penyelenggara': 0.20168067226890757,
#  'jakarta': 0.20304568527918782,
#  'kompascom': 0.19292604501607716,
#  '-': 0.19292604501607716,
#  'wakil': 0.2185792349726776,
#  'ketua': 0.22346368715083798,
#  'dpr': 0.22140221402214022,
#  'aman': 0.22684310018903592,
#  'damai': 0.20236087689713322,
#  'peserta': 0.17857142857142858,
#  'tanggung': 0.15748031496062992,
#  'pihak': 0.16877637130801687,
#  'aparat': 0.20304568527918782,
#  'pemerintahan': 0.21505376344086022,
#  'berlaku': 0.1724137931034483,
#  'adil': 0.18547140649149924,
#  'penyelenggaranya': 0.1566579634464752,
#  'kpu-nya': 0.1566579634464752,
#  'bawaslunya': 0.1566579634464752,
#  'birokrasi': 0.16901408450704225,
#  'akan': 0.15706806282722513,
#  'tercipta': 0.1736613603473227,
# ...

# %%
eigenvector_dict1
# Out:
# {'fadli': 0.34998388462035046,
#  'zon': 0.3347409858699912,
#  'keamanan': 0.24749397075034335,
#  'kedamaian': 0.1603686924749378,
#  'pemilu': 0.42176787452635534,
#  'ditentukan': 0.192900751144638,
#  'penyelenggara': 0.17391241607956687,
#  'jakarta': 0.09877648248298787,
#  'kompascom': 0.02855072732754674,
#  '-': 0.02037166518103722,
#  'wakil': 0.056459927480911394,
#  'ketua': 0.06500147369449592,
#  'dpr': 0.09944135580686579,
#  'aman': 0.1513602953884147,
#  'damai': 0.1574209267155334,
#  'peserta': 0.051924455211548357,
#  'tanggung': 0.023793908324332914,
#  'pihak': 0.047374228701522775,
#  'aparat': 0.22931349498208806,
#  'pemerintahan': 0.13881159100871615,
#  'berlaku': 0.1104016722457888,
#  'adil': 0.23142884426304783,
#  'penyelenggaranya': 0.0554541368525118,
#  'kpu-nya': 0.0554541368525118,
#  'bawaslunya': 0.0554541368525118,
#  'birokrasi': 0.054947535393277014,
#  'akan': 0.073907931216676,
#  'tercipta': 0.07701361769205255,
# ...

# %% [markdown]
# # betweenness tertinggi

# %%
sorted_betweenness1 = sorted(betweenness_dict1.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness2 = sorted(betweenness_dict2.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness3 = sorted(betweenness_dict3.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness4 = sorted(betweenness_dict4.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness5 = sorted(betweenness_dict5.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness6 = sorted(betweenness_dict6.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness7 = sorted(betweenness_dict7.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness8 = sorted(betweenness_dict8.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness9 = sorted(betweenness_dict9.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness10 = sorted(betweenness_dict10.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness11 = sorted(betweenness_dict11.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness12 = sorted(betweenness_dict12.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_betweenness_gabung = sorted(betweenness_dict_gabung.items(),
                           key = itemgetter(1),
                           reverse=True)

print("Top 10 nodes by betweenness centrality politik 1:")
for b in sorted_betweenness1[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 2:")
for b in sorted_betweenness2[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 3:")
for b in sorted_betweenness3[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 4:")
for b in sorted_betweenness4[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 5:")
for b in sorted_betweenness5[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 6:")
for b in sorted_betweenness6[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality olahraga 7:")
for b in sorted_betweenness7[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 8:")
for b in sorted_betweenness8[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 9:")
for b in sorted_betweenness9[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 10:")
for b in sorted_betweenness10[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 11:")
for b in sorted_betweenness11[:10]:
    print(b)
    
print("\nTop 10 nodes by betweenness centrality politik 12:")
for b in sorted_betweenness12[:10]:
    print(b)
    
print("\nTop 20 nodes by betweenness centrality politik gabung:")
for b in sorted_betweenness_gabung[:20]:
    print(b)
# Out:
# Top 10 nodes by betweenness centrality politik 1:
# ('pemilu', 0.27873477790494594)
# ('fadli', 0.265109012524979)
# ('zon', 0.22759492919156782)
# ('presiden', 0.18693730988899052)
# ('perbedaan', 0.18645891690009345)
# ('prabowo', 0.1688367188367187)
# ('wakil', 0.14601633582726023)
# ('partai', 0.11579511097368238)
# ('jokowi', 0.11082917277245001)
# ('sampai', 0.11078431372549019)
#
# Top 10 nodes by betweenness centrality politik 2:
# ('partai', 0.4936185390583859)
# ('pkb', 0.279854094666768)
# ('survei', 0.24589612227563099)
# ('persen', 0.12587915095744084)
# ('pemilu', 0.1015119955938413)
# ('efek', 0.10089137137163721)
# ('golkar', 0.09480268824379687)
# ('2019', 0.0768204259303724)
# ('legislatif', 0.07620376463521449)
# ('demokrat', 0.07250719014279103)
#
# Top 10 nodes by betweenness centrality politik 3:
# ('dukungan', 0.26080401289149335)
# ('2019', 0.22472664196837763)
# ('yenny', 0.20909170496691493)
# ('amin', 0.19326008103133063)
# ('jakarta', 0.19014469052957653)
# ...

# %% [markdown]
# # Closeness tertinggi

# %%
sorted_closeness1 = sorted(closeness_dict1.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness2 = sorted(closeness_dict2.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness3 = sorted(closeness_dict3.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness4 = sorted(closeness_dict4.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness5 = sorted(closeness_dict5.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness6 = sorted(closeness_dict6.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness7 = sorted(closeness_dict7.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness8 = sorted(closeness_dict8.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness9 = sorted(closeness_dict9.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness10 = sorted(closeness_dict10.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness11 = sorted(closeness_dict11.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness12 = sorted(closeness_dict12.items(),
                           key = itemgetter(1),
                           reverse=True)

sorted_closeness_gabung = sorted(closeness_dict_gabung.items(),
                           key = itemgetter(1),
                           reverse=True)

print("Top 10 nodes by closeness centrality politik 1:")
for b in sorted_closeness1[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 2:")
for b in sorted_closeness2[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 3:")
for b in sorted_closeness3[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 4:")
for b in sorted_closeness4[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 5:")
for b in sorted_closeness5[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 6:")
for b in sorted_closeness6[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 7:")
for b in sorted_closeness7[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 8:")
for b in sorted_closeness8[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 9:")
for b in sorted_closeness9[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 10:")
for b in sorted_closeness10[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality politik 11:")
for b in sorted_closeness11[:10]:
    print(b)
    
print("\nTop 10 nodes by closeness centrality olahraga 12:")
for b in sorted_closeness12[:10]:
    print(b)
    
print("\nTop 20 nodes by closeness centrality politik gabung:")
for b in sorted_closeness_gabung[:20]:
    print(b)
# Out:
# Top 10 nodes by closeness centrality politik 1:
# ('pemilu', 0.255863539445629)
# ('fadli', 0.25263157894736843)
# ('zon', 0.24048096192384769)
# ('presiden', 0.2357563850687623)
# ('baca', 0.23121387283236994)
# ('aman', 0.22684310018903592)
# ('kesempatan', 0.22556390977443608)
# ('demokratis', 0.2247191011235955)
# ('gerindra', 0.22429906542056074)
# ('ketua', 0.22346368715083798)
#
# Top 10 nodes by closeness centrality politik 2:
# ('partai', 0.36883116883116884)
# ('pkb', 0.3380952380952381)
# ('persen', 0.31555555555555553)
# ('golkar', 0.31072210065645517)
# ('2019', 0.30148619957537154)
# ('survei', 0.2976939203354298)
# ('papan', 0.29583333333333334)
# ('melibatkan', 0.2927835051546392)
# ('efek', 0.2862903225806452)
# ('potensial', 0.285140562248996)
#
# Top 10 nodes by closeness centrality politik 3:
# ('dukungan', 0.2613390928725702)
# ('keluarga', 0.25473684210526315)
# ('yenny', 0.25366876310272535)
# ('sikap', 0.2505175983436853)
# ('amin', 0.24845995893223818)
# ...

# %% [markdown]
# # eigenvector tertinggi

# %%
sorted_eigenvector1 = sorted(eigenvector_dict1.items(),
                           key = itemgetter(1),
                           reverse=True)

print("Top 20 nodes by eigenvector centrality politik 1:")
for b in sorted_eigenvector1[:20]:
    print(b)
# Out:
# Top 20 nodes by eigenvector centrality politik 1:
# ('pemilu', 0.42176787452635534)
# ('fadli', 0.34998388462035046)
# ('zon', 0.3347409858699912)
# ('keamanan', 0.24749397075034335)
# ('adil', 0.23142884426304783)
# ('aparat', 0.22931349498208806)
# ('kontestasi', 0.19308431033230838)
# ('ditentukan', 0.192900751144638)
# ('penyelenggara', 0.17391241607956687)
# ('kedamaian', 0.1603686924749378)
# ('damai', 0.1574209267155334)
# ('aman', 0.1513602953884147)
# ('pemerintahan', 0.13881159100871615)
# ('berjalan', 0.13878585282053552)
# ('menggembirakan', 0.12473347485673694)
# ('demokratis', 0.11418479112149395)
# ('berlaku', 0.1104016722457888)
# ('dpr', 0.09944135580686579)
# ('nilai', 0.09919411878639811)
# ('jakarta', 0.09877648248298787)
